# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
sys.path.append('%s/../' % os.getcwd())

import datetime
import pandas as pd
import numpy as np
import getpass

# %%
#importa as fórmulas do arquivo aluguel_offshore.py - note que este arquivo deverá estar na mesma pasta deste notebook
from aluguel_offshore import *

# %%
#pasta em que estão os arquivos no seu computador.
pasta = r'C:\Users\correigu\OneDrive - Banco BTG Pactual S.A\Desktop\aqruivos_offshore'
#pasta = r'C:\Users\correigu\OneDrive - Banco BTG Pactual S.A\Desktop\aqruivos_offshore\janfev'

# %%
#Class está definida no arquivo aluguel_offhsore.py que tem que estar na mesma pasta desse notebook
ubs, morgan, pras, bdwm, intc, ticker_diffs = ImportAluguelOffshore(pasta).import_files()
# Out:
# 130 aqrivos do ubs importados
# 234 aqrivos da morgan importados
# 113 aqrivos do Calypso PROP+ASSET importados
# 111 aqrivos do Calypso BD+WM importados
# 123 aqrivos do Calypso INTC importados

# %% [markdown]
# # Ajustes base

# %%
#Ajustes da base estão definidos no aluguel_offshore.py que auxilia nesse notebook
#Eventual quadrado rosa abaixo não significa que houve erro!
pb = get_pb(morgan, ubs)
calypso = ajuste_calypso(pras, bdwm, intc)
calypso_1 = calypso.copy()
calypso_1['acc'] = calypso_1['conta_pb'].map(dict_contas)


pb, calypso = ajuste_dias(pb, calypso)


calypso = limpa_calypso(calypso)
# Out:
# C:\Users\correigu\Python\aluguel_offshore\aluguel_offshore.py:176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   morgan['data_ref'] = np.where(morgan['data_ref'].dt.weekday==6, morgan['data_ref']-datetime.timedelta(2), morgan['data_ref'])

# %%
#Fórmula que também está definida no arquivo aluguel_offshore.py
mapa_dict = mapeamento_tickers(pb, calypso)
# Out:
# C:\Users\correigu\Python\aluguel_offshore\aluguel_offshore.py:221: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   on_cusip_2['ticker_novos'])

# %%
ticker_diffs = ticker_diffs.rename(columns={
    'Stock':'ticker',
    'Isin':'isin',
    'Cusip':'cusip'
})

mapa_dict_tickers = mapeamento_tickers(ticker_diffs, calypso)
ticker_diffs['ticker'] = ticker_diffs['ticker'].map(mapa_dict_tickers)
# Out:
# C:\Users\correigu\Python\aluguel_offshore\aluguel_offshore.py:221: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   on_cusip_2['ticker_novos'])

# %%
#Aqui ficam os ajustes que eu já sei que são necessáiros para esse range de tempo. qualquer coisa é só adicionar nesse dicionátio
dict_ajustes = {
    'VALE':'VALE US',
     'CX':'CX US',
    'DHT':'DHT US',
    'SALT':'SALT US',
    'SIG':'SIG US',
    'ENIC':'ENIC US',
    'CPB':'CPB US',
    'SFIX':'SFIX US',
    'BSMX':'BSMX US',
    'ECH':'ECH US',
    'DRI':'DRI US',
    'SONC':'SONC US',
    'JCP':'JCP US',
    'BBY':'BBY US',
    'ALFAA':'ALFAA MM',
    'DPZ':'DPZ US',
    'XLE':'XLE US',
    'DG':'DG US',
    'BBBY':'BBBY US',
    'HOG':'HOG US',
    'TLV1':'TLEVICPO MM',
    'KIMBERA':'KIMBERA MM',
    'MFRISCOA':'MFRISCOA MM',
    'LIVEPOLC':'LIVEPOLC MM',
    'RGR':'RGR US',
    'GFINBURO':'GFINBURO MM',
    'FUNO11':'FUNO11 MM',
    'ICA*':'ICA* MM',
    'PINFRA*':'PINFRA* MM',
    'DNKN':'DNKN US',
    'VESTA*':'VESTA* MM',
    'GENTERA*':'GENTERA* MM',
    'KHC':'KHC US',
    'WU':'WU US',
    'MELI':'MELI US',
    'TGT':'TGT US',
    'CAKE':'CAKE US',
    'NFLX':'NFLX US',
    'COHU':'COHU US',
    'ORCL':'ORCL US',
    'FB':'FB US',
    'LE':'LE US',
    'CXO':'CXO US',
    'GOLD':'GOLD US',
    'FMX':'FMX US',
    'VIV':'VIV US',
    'TSU':'TSU US',
    'EC':'EC US',
    'BJRI':'BJRI US',
    'DKS':'DKS US',
    'GILD':'GILD US',
    'GFI':'GFI US',
    'MCK':'MCK US',
    'FCAU':'FCAU US',
    'ARCO':'ARCO US'
}

# %%
#Essa linha adicionar o dicionário acima ao dicionário do mapeamento que está 3 celulas acima (aproximadamente)
#Despois de dar essa atualizada, é necessário rodar a linha de mapeamento novamente, a que está umas 2 celulas acima
#a que tem um monte de comentários
mapa_dict.update(dict_ajustes)

# %%
#Aqui é aplicado o dicionário para criar uma coluna que mapeia tickers do pb pros tickers do calypso
#Pode ser que arquivos fiquem fora do mapeamento acima por causa de problemas com ticker, isin ou cusip
#Quando isso ocorrer, é necessário fazer o mapeamento manual dos faltantes, adicionando no dicionário abaixo esses tickers
#Adicionamos da seguinte forma: adiciona-se um linha no dicionário abaixo com o Enter. Então coloca-se o nome que está
#no pb entre aspas, colocamos dois pontos e colocamos o nome que está no calypso.
pb['ticker_ajuste'] = pb['ticker'].apply(lambda x: mapeamento(mapa_dict, x))

# %%
#Essa linha serve somente para você checkar no pb quais tickers não foram mapeados. se você colcoar um # depois de True],
#você consegue ver as linhas que não foram mapeadas e todas as informações que estão contidas nelas. Caso haja isin e cusip,
#É provavel que não tenha o ticker, por isso houve o problema. nesse caso, é preciso fazer um ajuste análogo ao que foi feito
#pro ticker LIT mais acima. se não souber se virar, contatar guilherme.correia@btgpactual.com
#Se você tirar o # entre True]#['ticker'] você poderá ver todos os tickers que apresentaram problemas e procurar por
#eles na linha abaixo
pb[pb['ticker_ajuste'].isnull()==True]['ticker'].drop_duplicates()
# Out:
# 9                 UGP
# 1240            CNNEF
# 2306     BSMXB_OLD.MX
# 3626           EFGINT
# 11201             NaN
# Name: ticker, dtype: object

# %%
#Aqui você procura pelos tickers que são mostrados na linha acima. você procura por uma parte do ticker somente, para ver se
#encontra algo na base do calypso. O código .contains('something') procura por esse padrão nos tickers do calypso. é como um *
# * nas linhas de procurar de qualquer programa.
#Caso você encontra de fato algo, vocêdxo adiciona à lista do dicionário dict_ajustes o ticker da linha acima e dessa linha
#isso completa o mapeamento do ticker. Não esquece de rodar novamente a linha de mapeamento depois de adicionar algo ao
#dicionário
calypso[calypso['ticker'].str.contains('ARCO')==True].ticker.drop_duplicates()
# Out:
# Series([], Name: ticker, dtype: object)

# %%
#Essa linha deve ser executada depois de terem sido feitos todos os ajustes, porque ela troca os nomes das colunas
#serve para que em ambas as bases a coluna 'ticker' sejam comunicáveis
pb = pb.rename(columns={
    'ticker':'ticker_antigo',
    'ticker_ajuste':'ticker'
})

# %% [markdown]
# # Batimento mensal

# %%
#Escolha o mês e ano do batimento
mes_ref = 'mai'
ano_ref = 2018
data = '2018-06-07'
tipo = 'month'

# %% [markdown]
# #### Bate os arquivos do calypso contra o pb para ver se todos os que estão no calypso estão no pb

# %%
calypso_month, pb_month, calypso_month_acumulado, pb_month_acumulado = \
                        get_month_or_day_batimento(calypso, pb,mes_ref, ano_ref, data, referencia = tipo)
# Out:
# Você está fazendo o batimento referente a mai/2018

# %%
pvt = check_days(calypso_month, pb_month)
pvt
# Out:
#              check
# tipo       calypso                         pb
# acc          int_c ms_cayman ubs_cayman int_c ms_cayman ubs_cayman
# data_ref
# 2018-05-01       1         1          1     1         1          1
# 2018-05-02       1         1          1     1         1          1
# 2018-05-03       1         1          1     1         1          1
# 2018-05-04       1         1          1     1         1          1
# 2018-05-07       1         1          1     1         1          1
# 2018-05-08       1         1          1     1         1          1
# 2018-05-09       1         1          1     1         1          1
# 2018-05-10       1         1          1     1         1          1
# 2018-05-11       1         1          1     1         1          1
# 2018-05-14       1         1          1     1         1          1
# 2018-05-15       1         1          1     1         1          1
# 2018-05-16       1         1          1     1         1          1
# 2018-05-17       1         1          1     1         1          1
# 2018-05-18       1         1          1     1         1          1
# 2018-05-21       1         1          1     1         1          1
# 2018-05-22       1         1          1     1         1          1
# 2018-05-23       1         1          1     1         1          1
# 2018-05-24       1         1          1     1         1          1
# 2018-05-25       1         1          1     1         1          1
# 2018-05-28       1         1          1     1         1          1
# 2018-05-29       1         1          1     1         1          1
# 2018-05-30       1         1          1     1         1          1
# 2018-05-31       1         1          1     1         1          1

# %%
pb_month, calypso_batimento = ajustes_pb_calypso_month(pb_month, calypso_month, dict_contas)
try:
    pb_month_acumulado, calypso_batimento_acumulado = \
                            ajustes_pb_calypso_month(pb_month_acumulado, calypso_month_acumulado, dict_contas)
except:
    print ('Arquivos não acumuláveis')
# Out:
# Arquivos não acumuláveis

# %%
sobra_destino, sobra_origem, batido, divergentes, corrigidos, n_batidos, distribuidos = \
                                            batimento_calypso_pb(pb_month, calypso_batimento, ticker_diffs)
# Out:
# 7.007098694756131 pct dos trades estão no prime broker, mas não acharam correspondência no Calypso
# 0.9028794533918985 pct dos trades foram achados no calypso, mas não têm correspondência no prime broker

# %%
try:
    sobra_destino_acumulado, sobra_origem_acumulado, batido_acumulado, divergentes_acumulado, corrigidos_acumulado,\
    n_batidos_acumulado, distribuidos_acumulado = \
                batimento_calypso_pb(pb_month_acumulado, calypso_batimento_acumulado, ticker_diffs)
except:
    print ('Arquivos não acumuláveis')
# Out:
# Arquivos não acumuláveis

# %% [markdown]
# ### Distribuição por books

# %%
#Pega as informações do calypso para o mês de referência. 
calypso_month_books, calypso_month_books_acumulado = get_calypso_month_books(calypso,mes_ref, ano_ref, data, referencia = tipo)
# Out:
# Você está fazendo a distribuição referente a mai/2018

# %%
calypso_month_books, abertura, abertura_n_batidos = explode_books(calypso_month_books, calypso_batimento, distribuidos)
# Out:
# Ajustes na base calypso estão completos
# Ajustes de quantidades estão completos
# Checando quais trades ficaram fora do batimento

# %%
try:
    calypso_month_books_acumulado, abertura_acumulado, abertura_n_batidos_acumulado = \
                        explode_books(calypso_month_books_acumulado, calypso_batimento_acumulado, distribuidos_acumulado)
except:
    print ('calypso_month_books_acumulado provavelmente está vazio')
# Out:
# calypso_month_books_acumulado provavelmente está vazio

# %%
abertura
# Out:
#        conta_pb  conta                agent   data_ref  quantidade_book  \
# 0     038CDBD08  ASSET  MORGAN STANLEY & CO 2018-05-01          -5331.0
# 1     038CDBD08  ASSET  MORGAN STANLEY & CO 2018-05-01          -9434.0
# 2     038CDCN39  ASSET  MORGAN STANLEY & CO 2018-05-01        -203208.0
# 3     038CDCN39  ASSET  MORGAN STANLEY & CO 2018-05-01       -2888800.0
# 4      75202213  ASSET   UBS SECURITIES LLC 2018-05-01          -9930.0
# 5      75202213  ASSET   UBS SECURITIES LLC 2018-05-01         -70510.0
# 6     038CDCN39  ASSET  MORGAN STANLEY & CO 2018-05-01         -30036.0
# 7      75202213  ASSET   UBS SECURITIES LLC 2018-05-01         -36660.0
# 8     038CDBD08  ASSET  MORGAN STANLEY & CO 2018-05-01       -4335432.0
# 10    038CDBD08  ASSET  MORGAN STANLEY & CO 2018-05-01        -201211.0
# 11    038CDBD08  ASSET  MORGAN STANLEY & CO 2018-05-01         -16046.0
# 12     75202213  ASSET   UBS SECURITIES LLC 2018-05-01          -1050.0
# 13    038CDBD08  ASSET  MORGAN STANLEY & CO 2018-05-01           -346.0
# 14    038CDBD08  ASSET  MORGAN STANLEY & CO 2018-05-01          -6551.0
# 15    038CDBD08  ASSET  MORGAN STANLEY & CO 2018-05-01           -260.0
# 16    038CDCN39  ASSET  MORGAN STANLEY & CO 2018-05-01         -90652.0
# 18    038CDBD08  ASSET  MORGAN STANLEY & CO 2018-05-01          -4357.0
# 19    038CDCN39  ASSET  MORGAN STANLEY & CO 2018-05-01         -73695.0
# 20    038CDBD08  ASSET  MORGAN STANLEY & CO 2018-05-01        -149169.0
# 21    038CDBD08  ASSET  MORGAN STANLEY & CO 2018-05-01          17400.0
# 23    038CDCN39  ASSET  MORGAN STANLEY & CO 2018-05-01      -18636198.0
# 24    038CDBD08  ASSET  MORGAN STANLEY & CO 2018-05-01          -2802.0
# 25    038CDBD08  ASSET  MORGAN STANLEY & CO 2018-05-01         -62668.0
# 26    038CDBD08  ASSET  MORGAN STANLEY & CO 2018-05-01          25356.0
# 28     75202215  ASSET   UBS SECURITIES LLC 2018-05-01          -9580.0
# 29     75202213  ASSET   UBS SECURITIES LLC 2018-05-01         -30000.0
# 30     75202213  ASSET   UBS SECURITIES LLC 2018-05-01         -16000.0
# 31    038CDBD08  ASSET  MORGAN STANLEY & CO 2018-05-01          -6868.0
# 32    038CDBD08  ASSET  MORGAN STANLEY & CO 2018-05-01            546.0
# 33    038CDBD08  ASSET  MORGAN STANLEY & CO 2018-05-01             -2.0
# ...         ...    ...                  ...        ...              ...
# 5636  038CDB895  INT C  MORGAN STANLEY & CO 2018-05-30        -735742.0
# 5637  038CDB895  INT C  MORGAN STANLEY & CO 2018-05-30        -485532.0
# 5638  038CDB895  INT C  MORGAN STANLEY & CO 2018-05-30          -1500.0
# 5639  038CDB895  INT C  MORGAN STANLEY & CO 2018-05-30        -567700.0
# 5640  038CDB895  INT C  MORGAN STANLEY & CO 2018-05-30          -8409.0
# 5641  038CDB895  INT C  MORGAN STANLEY & CO 2018-05-30         -11342.0
# 5642  038CDB895  INT C  MORGAN STANLEY & CO 2018-05-31         -53767.0
# 5643  038CDB895  INT C  MORGAN STANLEY & CO 2018-05-31          -1600.0
# 5644  038CDB895  INT C  MORGAN STANLEY & CO 2018-05-31        -200000.0
# 5645  038CDB895  INT C  MORGAN STANLEY & CO 2018-05-31           -765.0
# 5646  038CDB895  INT C  MORGAN STANLEY & CO 2018-05-31           -760.0
# 5647  038CDB895  INT C  MORGAN STANLEY & CO 2018-05-31           -400.0
# 5648  038CDB895  INT C  MORGAN STANLEY & CO 2018-05-31         -10200.0
# 5649  038CDB895  INT C  MORGAN STANLEY & CO 2018-05-31         -22200.0
# 5650  038CDB895  INT C  MORGAN STANLEY & CO 2018-05-31          -5700.0
# 5651  038CDB895  INT C  MORGAN STANLEY & CO 2018-05-31         -10268.0
# 5652  038CDB895  INT C  MORGAN STANLEY & CO 2018-05-31          -8568.0
# 5653  038CDB895  INT C  MORGAN STANLEY & CO 2018-05-31           -450.0
# 5654  038CDB895  INT C  MORGAN STANLEY & CO 2018-05-31           1600.0
# 5655  038CDB895  INT C  MORGAN STANLEY & CO 2018-05-31         200000.0
# 5656  038CDB895  INT C  MORGAN STANLEY & CO 2018-05-31           -210.0
# 5657  038CDB895  INT C  MORGAN STANLEY & CO 2018-05-31       -1447246.0
# 5658  038CDB895  INT C  MORGAN STANLEY & CO 2018-05-31           -300.0
# 5659  038CDB895  INT C  MORGAN STANLEY & CO 2018-05-31        -735742.0
# 5660  038CDB895  INT C  MORGAN STANLEY & CO 2018-05-31        -485532.0
# 5661  038CDB895  INT C  MORGAN STANLEY & CO 2018-05-31          -1500.0
# 5662  038CDB895  INT C  MORGAN STANLEY & CO 2018-05-31         -17100.0
# 5663  038CDB895  INT C  MORGAN STANLEY & CO 2018-05-31        -567700.0
# 5664  038CDB895  INT C  MORGAN STANLEY & CO 2018-05-31          -9609.0
# 5665  038CDB895  INT C  MORGAN STANLEY & CO 2018-05-31         -11342.0
#
#                               book       ticker          isin      cusip  \
# 0           13F_CONS_N_CYCL.CAYMAN      RDUS US  US7504692077  750469207
# 1                  13F_INDU.CAYMAN      SBLK US  MHY8162K2046  Y8162K105
# 2            MEX_DIRECIONAL.CAYMAN      BSMX US  US05969B1035  05969B103
# 3            MEX_DIRECIONAL.CAYMAN       AMX US  US02364W1053  02364W105
# 4     SICAV LATAM HEDGE.CAYMAN_UBS       ECH US  US4642866408  464286640
# 5     SICAV LATAM HEDGE.CAYMAN_UBS       EWZ US  US4642864007  464286400
# 6            MEX_DIRECIONAL.CAYMAN       ASR US  US40051E2028  40051E202
# 7     SICAV LATAM HEDGE.CAYMAN_UBS       EWW US  US4642868222  464286822
# 8             LATAM_TELECOM.CAYMAN      AMXL MM  MXP001691213        NaN
# 10                 13F_INDU.CAYMAN       DHT US  MHY2065G1219        NaN
# 11           INTRADAY_PAIRS.CAYMAN       BAC US  US0605051046  060505104
# 12             PRIVATE_DEFAULT_UBS       TGT US  US87612E1064  87612E106
# 13          13F_CONS_N_CYCL.CAYMAN       MCK US  US58155Q1031  58155Q103
# 14            13F_CONS_CYCL.CAYMAN      BJRI US  US09180C1062  09180C106
# 15            13F_CONS_CYCL.CAYMAN      CPRT US  US2172041061  217204106
# 16           MEX_DIRECIONAL.CAYMAN       PAC US  US4005061019  400506101
# 18                 13F_INDU.CAYMAN      FELE US  US3535141028  353514102
# 19           MEX_DIRECIONAL.CAYMAN       KOF US  US1912411089  191241108
# 20            LATAM_TELECOM.CAYMAN       AMX US  US02364W1053  02364W105
# 21                  HDG_MEX.Cayman       EWW US  US4642868222  464286822
# 23           MEX_DIRECIONAL.CAYMAN  CEMEXCPO MM  MXP225611567        NaN
# 24                 13F_INDU.CAYMAN      ITRI US  US4657411066  465741106
# 25                 13F_COMM.CAYMAN       IYZ US  US4642877132  464287713
# 26          13F_CONS_N_CYCL.CAYMAN       XLP US  US81369Y3080  81369Y308
# 28                TREAS_OPS.CAYMAN       KHC US  US5007541064  500754106
# 29                  BD_CLIENTS_UBS      PAGS US  KYG687071012        NaN
# 30             PRIVATE_DEFAULT_UBS      PAGS US  KYG687071012        NaN
# 31          13F_CONS_N_CYCL.CAYMAN       XON US  US46122T1025  46122T102
# 32                   QTS_US.CAYMAN       PXD US  US7237871071  723787107
# 33                   QTS_US.CAYMAN       PSX US  US7185461040  718546104
# ...                            ...          ...           ...        ...
# 5636             LOCAL_ADR_MR.INTC      VALE US  US91912E1055  91912E105
# 5637             LOCAL_ADR_MR.INTC       PBR US  US71654V4086  71654V408
# 5638                LOCAL_ADR_INTC      ITUB US  US4655621062  465562106
# 5639          ACOES_OFFSHORE_.INTC       FMG AU  AU000000FMG4          .
# 5640                LOCAL_ADR_INTC       PBR US  US71654V4086  71654V408
# 5641           INTRADAY_PAIRS.INTC      VALE US  US91912E1055  91912E105
# 5642                LOCAL_ADR_INTC      VALE US  US91912E1055  91912E105
# 5643           ACOES_OFFSHORE_INTC       BAK US  US1055321053  105532105
# 5644           ACOES_OFFSHORE_INTC       PBR US  US71654V4086  71654V408
# 5645                LOCAL_ADR_INTC     PBR/A US  US71654V1017  71654V101
# 5646                LOCAL_ADR_INTC       TSU US  US88706P2056  88706P205
# 5647          ACOES_OFFSHORE_.INTC       EWZ US  US4642864007  464286400
# 5648          ACOES_OFFSHORE_.INTC      GAPB MM  MX01GA000004        NaN
# 5649          ACOES_OFFSHORE_.INTC       LTM US  US51817R1068  51817R106
# 5650          ACOES_OFFSHORE_.INTC      SCCO US  US84265V1052  84265V105
# 5651                LOCAL_ADR_INTC       BAK US  US1055321053  105532105
# 5652           INTRADAY_PAIRS.INTC       EWZ US  US4642864007  464286400
# 5653                LOCAL_ADR_INTC       CBD US  US20440T2015  20440T201
# 5654          ACOES_OFFSHORE_.INTC       BAK US  US1055321053  105532105
# 5655          ACOES_OFFSHORE_.INTC       PBR US  US71654V4086  71654V408
# 5656          ACOES_OFFSHORE_.INTC       PAC US  US4005061019  400506101
# 5657                LOCAL_ADR_INTC       EBR US  US15234Q2075  15234Q207
# 5658                LOCAL_ADR_INTC       SID US  US20440W1053  20440W105
# 5659             LOCAL_ADR_MR.INTC      VALE US  US91912E1055  91912E105
# 5660             LOCAL_ADR_MR.INTC       PBR US  US71654V4086  71654V408
# 5661                LOCAL_ADR_INTC      ITUB US  US4655621062  465562106
# 5662                LOCAL_ADR_INTC       ERJ US  US29082A1079  29082A107
# 5663          ACOES_OFFSHORE_.INTC       FMG AU  AU000000FMG4          .
# 5664                LOCAL_ADR_INTC       PBR US  US71654V4086  71654V408
# 5665           INTRADAY_PAIRS.INTC      VALE US  US91912E1055  91912E105
#
#      currency month  year         acc  quantidade_ticker          qt  \
# 0         USD   mai  2018   ms_cayman            -5331.0     -5331.0
# 1         USD   mai  2018   ms_cayman            -9434.0     -9434.0
# 2         USD   mai  2018   ms_cayman          -203208.0   -203208.0
# 3         USD   mai  2018   ms_cayman         -3037969.0  -3037969.0
# 4         USD   mai  2018  ubs_cayman           -40057.0    -40057.0
# 5         USD   mai  2018  ubs_cayman           -70510.0    -70510.0
# 6         USD   mai  2018   ms_cayman           -30036.0    -30036.0
# 7         USD   mai  2018  ubs_cayman         -1001297.0  -1001297.0
# 8         MXN   mai  2018   ms_cayman         -4335432.0  -4335432.0
# 10        USD   mai  2018   ms_cayman          -201211.0   -201211.0
# 11        USD   mai  2018   ms_cayman           -12299.0    -12299.0
# 12        USD   mai  2018  ubs_cayman            -1050.0     -1050.0
# 13        USD   mai  2018   ms_cayman             -346.0      -346.0
# 14        USD   mai  2018   ms_cayman            -6551.0     -6551.0
# 15        USD   mai  2018   ms_cayman             -260.0      -260.0
# 16        USD   mai  2018   ms_cayman           -90652.0    -90652.0
# 18        USD   mai  2018   ms_cayman            -4357.0     -4357.0
# 19        USD   mai  2018   ms_cayman           -73695.0    -73695.0
# 20        USD   mai  2018   ms_cayman         -3037969.0  -3037969.0
# 21        USD   mai  2018   ms_cayman          -154350.0   -154350.0
# 23        MXN   mai  2018   ms_cayman        -18636198.0 -18636198.0
# 24        USD   mai  2018   ms_cayman            -2802.0     -2802.0
# 25        USD   mai  2018   ms_cayman           -62668.0    -62668.0
# 26        USD   mai  2018   ms_cayman            -8244.0     -8244.0
# 28        USD   mai  2018  ubs_cayman            -9580.0     -9580.0
# 29        USD   mai  2018  ubs_cayman           -46000.0    -46000.0
# 30        USD   mai  2018  ubs_cayman           -46000.0    -46000.0
# 31        USD   mai  2018   ms_cayman            -6868.0     -6868.0
# 32        USD   mai  2018   ms_cayman              -33.0       -33.0
# 33        USD   mai  2018   ms_cayman               -2.0        -2.0
# ...       ...   ...   ...         ...                ...         ...
# 5636      USD   mai  2018       int_c          -600851.0   -600851.0
# 5637      USD   mai  2018       int_c          -493941.0   -493941.0
# 5638      USD   mai  2018       int_c            -1500.0     -1500.0
# 5639      AUD   mai  2018       int_c          -567700.0   -567700.0
# 5640      USD   mai  2018       int_c          -493941.0   -493941.0
# 5641      USD   mai  2018       int_c          -600851.0   -600851.0
# 5642      USD   mai  2018       int_c          -800851.0   -800851.0
# 5643      USD   mai  2018       int_c           -10268.0    -10268.0
# 5644      USD   mai  2018       int_c          -495141.0   -495141.0
# 5645      USD   mai  2018       int_c             -765.0      -765.0
# 5646      USD   mai  2018       int_c             -760.0      -760.0
# 5647      USD   mai  2018       int_c            -8968.0     -8968.0
# 5648      MXN   mai  2018       int_c           -10200.0    -10200.0
# 5649      USD   mai  2018       int_c           -22200.0    -22200.0
# 5650      USD   mai  2018       int_c            -5700.0     -5700.0
# 5651      USD   mai  2018       int_c           -10268.0    -10268.0
# 5652      USD   mai  2018       int_c            -8968.0     -8968.0
# 5653      USD   mai  2018       int_c             -450.0      -450.0
# 5654      USD   mai  2018       int_c           -10268.0    -10268.0
# 5655      USD   mai  2018       int_c          -495141.0   -495141.0
# 5656      USD   mai  2018       int_c             -210.0      -210.0
# 5657      USD   mai  2018       int_c         -1447246.0  -1447246.0
# 5658      USD   mai  2018       int_c             -300.0      -300.0
# 5659      USD   mai  2018       int_c          -800851.0   -800851.0
# 5660      USD   mai  2018       int_c          -495141.0   -495141.0
# 5661      USD   mai  2018       int_c            -1500.0     -1500.0
# 5662      USD   mai  2018       int_c           -17100.0    -17100.0
# 5663      AUD   mai  2018       int_c          -567700.0   -567700.0
# 5664      USD   mai  2018       int_c          -495141.0   -495141.0
# 5665      USD   mai  2018       int_c          -800851.0   -800851.0
#
#       accrual_adjusted  quantidade      id  status  quantidade_conta_pb
# 0               -11.07     -5331.0   402.0  batido              -5331.0
# 1                -9.05     -9434.0   409.0  batido              -9434.0
# 2               -31.03   -203208.0   339.0  batido            -203208.0
# 3             -1153.79  -3037969.0   322.0  batido           -2888800.0
# 4               -88.70    -40057.0  3034.0  batido              -9930.0
# 5               102.26    -70510.0  3036.0  batido             -70510.0
# 6              -190.77    -30036.0   329.0  batido             -30036.0
# 7              -354.00  -1001297.0  3035.0  batido             -36660.0
# 8             -2244.13  -4335432.0   323.0  batido           -4335432.0
# 10              -15.30   -201211.0   351.0  batido            -201211.0
# 11               -7.68    -12299.0   334.0  batido             -12299.0
# 12                2.88     -1050.0  3059.0  batido              -1050.0
# 13               -1.11      -346.0   383.0  batido               -346.0
# 14               -7.71     -6551.0   336.0  batido              -6551.0
# 15               -0.28      -260.0   347.0  batido               -260.0
# 16             -408.42    -90652.0   393.0  batido             -90652.0
# 18               -4.01     -4357.0   358.0  batido              -4357.0
# 19             -241.60    -73695.0   377.0  batido             -73695.0
# 20            -1153.79  -3037969.0   322.0  batido            -149169.0
# 21             -510.77   -154350.0   357.0  batido            -154350.0
# 23            -6521.25 -18636198.0   342.0  batido          -18636198.0
# 24               -3.82     -2802.0   374.0  batido              -2802.0
# 25             -110.60    -62668.0   375.0  batido             -62668.0
# 26               -8.59     -8244.0   433.0  batido              -8244.0
# 28               20.60     -9580.0  3045.0  batido              -9580.0
# 29               54.93    -46000.0  3053.0  batido             -46000.0
# 30               54.93    -46000.0  3053.0  batido             -46000.0
# 31              -12.72     -6868.0   434.0  batido              -6868.0
# 32               -0.14       -33.0   399.0  batido                -33.0
# 33                0.00        -2.0   397.0  batido                 -2.0
# ...                ...         ...     ...     ...                  ...
# 5636           -169.49   -600851.0   303.0  batido            -600851.0
# 5637           -122.66   -493941.0   298.0  batido            -493941.0
# 5638             -0.36     -1500.0   295.0  batido              -1500.0
# 5639            -86.69   -567700.0   293.0  batido            -567700.0
# 5640           -122.66   -493941.0   298.0  batido            -493941.0
# 5641           -169.49   -600851.0   303.0  batido            -600851.0
# 5642           -226.91   -800851.0   319.0  batido            -800851.0
# 5643            -26.30    -10268.0   304.0  batido             -10268.0
# 5644           -122.35   -495141.0   314.0  batido            -495141.0
# 5645             -0.17      -765.0   315.0  batido               -765.0
# 5646             -0.28      -760.0   318.0  batido               -760.0
# 5647             -6.65     -8968.0   308.0  batido              -8968.0
# 5648            -51.82    -10200.0   310.0  batido             -10200.0
# 5649            -13.32    -22200.0   312.0  batido             -22200.0
# 5650             -7.36     -5700.0   316.0  batido              -5700.0
# 5651            -26.30    -10268.0   304.0  batido             -10268.0
# 5652             -6.65     -8968.0   308.0  batido              -8968.0
# 5653             -0.34      -450.0   305.0  batido               -450.0
# 5654            -26.30    -10268.0   304.0  batido             -10268.0
# 5655           -122.35   -495141.0   314.0  batido            -495141.0
# 5656             -0.79      -210.0   313.0  batido               -210.0
# 5657          -1238.20  -1447246.0   306.0  batido           -1447246.0
# 5658             -0.08      -300.0   317.0  batido               -300.0
# 5659           -226.91   -800851.0   319.0  batido            -800851.0
# 5660           -122.35   -495141.0   314.0  batido            -495141.0
# 5661             -0.36     -1500.0   311.0  batido              -1500.0
# 5662             -8.57    -17100.0   307.0  batido             -17100.0
# 5663            -89.03   -567700.0   309.0  batido            -567700.0
# 5664           -122.35   -495141.0   314.0  batido            -495141.0
# 5665           -226.91   -800851.0   319.0  batido            -800851.0
#
# [4839 rows x 20 columns]

# %%
abertura_n_batidos
# Out:
# Empty DataFrame
# Columns: [conta_pb, conta, agent, data_ref, quantidade_book, book, ticker, isin, cusip, currency, month, year, acc, quantidade_ticker, qt, accrual_adjusted, quantidade, id, status, quantidade_conta_pb]
# Index: []

# %%
abertura, abertura_batidos, abertura_n_batidos, bate_soma, bate_soma_pb, check = \
                                        ajuste_abertura_checs(abertura, abertura_n_batidos, pb_month)
# Out:
# Ajustes nas quantidades e alocação percentual feitos
# Ajustes nas bases feitos
# Geradas os dataframes de batimento
# Dataframe de batimento gerado

# %%
try:
    abertura_acumulado, abertura_batidos_acumulado, abertura_n_batidos_acumulado, bate_soma_acumulado, bate_soma_pb_acumulado, \
                                    check_acumulado =  \
                            ajuste_abertura_checs(abertura_acumulado, abertura_n_batidos_acumulado, pb_month_acumulado)
except:
    print ('calypso_month_books_acumulado provavelmente está vazio')
# Out:
# calypso_month_books_acumulado provavelmente está vazio

# %%
check
# Out:
#           acc currency  quantidade_pb  quantidade_calypso    bate_qt  \
# 0       int_c      AUD    -13057100.0         -13057100.0        0.0
# 1       int_c      MXN      -234600.0           -234600.0        0.0
# 2       int_c      USD    -36590951.0         -36590951.0        0.0
# 3   ms_cayman      EUR      -748223.0           -748223.0        0.0
# 4   ms_cayman      GBP         -690.0              -690.0        0.0
# 5   ms_cayman      MXN   -470027247.0        -470027247.0        0.0
# 6   ms_cayman      USD   -151990449.0        -144542802.0 -7447647.0
# 7  ubs_cayman      MXN   -241427869.0        -232459688.0 -8968181.0
# 8  ubs_cayman      USD    -70295270.0         -70009921.0  -285349.0
#
#     custos_pb  custos_batidos   bate_custos  bate_custos_pct
# 0    -2797.75        -2797.75  0.000000e+00         1.000000
# 1    -1663.57        -1663.57  0.000000e+00         1.000000
# 2   -20437.24       -20437.24 -7.275958e-12         1.000000
# 3     -467.13         -467.13  1.136868e-13         1.000000
# 4       -1.16           -1.16  0.000000e+00         1.000000
# 5  -982264.52      -982264.52 -2.328306e-10         1.000000
# 6  -148173.57      -148157.11 -1.646000e+01         1.000111
# 7 -1016748.48      -979912.33 -3.683615e+04         1.037591
# 8    33339.25        33401.42 -6.217000e+01         0.998139

# %% [markdown]
# ### Abertura por WM

# %%
#from aluguel_offshore import *

# %%
pb_wm = abertura[(abertura['book'].str.contains('PRIVATE'))|(abertura['book'].str.contains('CLIENT'))]

# %%
try:
    pb_wm_acumulado = abertura_acumulado[(abertura_acumulado['book'].str.contains('PRIVATE'))\
                                         |(abertura_acumulado['book'].str.contains('CLIENT'))]
except:
    print ('calypso_month_books_acumulado provavelmente está vazio')
# Out:
# calypso_month_books_acumulado provavelmente está vazio

# %%
calypso_wm, calypso_wm_grouped, calypso_wm_acumulado, calypso_wm_grouped_acumulado = \
                                ajuste_wm(bdwm, data ,mes_ref, ano_ref, referencia = tipo)
# Out:
# Sem valores de acumulado

# %%
batimento_wm = pd.merge(pb_wm, calypso_wm_grouped, on=['data_ref', 'book', 'ticker', 'currency'], how='left')\
                                                                                    .drop('year', axis=1)

try:
    batimento_wm_acumulado = pd.merge(pb_wm_acumulado, calypso_wm_grouped_acumulado, \
                                      on=['data_ref', 'book', 'ticker', 'currency'], how='left').drop('year', axis=1)
except:
    print ('calypso_month_books_acumulado provavelmente está vazio')
# Out:
# calypso_month_books_acumulado provavelmente está vazio

# %%
batimento_wm_distrib, abertura_batidos_final, n_batimento_wm_distrib, n_distrib_wm, batimento_wm_sobra_origem = \
                                    get_batimento_wm_distb(batimento_wm, calypso_wm, abertura_batidos)
    
abertura_batidos_final = abertura_batidos_final.rename(columns={
    'conta':'arquivo_origem',
    'conta_pb':'conta'    
}).reset_index(drop=True)
# Out:
# C:\Users\correigu\Python\aluguel_offshore\aluguel_offshore.py:325: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   batimento_wm_sobra_origem = batimento_wm_batidos[~batimento_wm_batidos['id'].isin(batimento_wm_distrib['id'].drop_duplicates())]
# C:\Users\correigu\Python\aluguel_offshore\aluguel_offshore.py:336: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   abertura_batidos['conta_pb'] = abertura_batidos['acc'].copy()

# %%
batimento_wm_distrib
# Out:
#      conta_pb       agent   data_ref  quantidade_book                 book  \
# 0     1682709  BTG CAYMAN 2018-05-01             -350  PRIVATE_DEFAULT_UBS
# 1     1682709  BTG CAYMAN 2018-05-01             -100  PRIVATE_DEFAULT_UBS
# 11      46537  BTG CAYMAN 2018-05-01           -16000  PRIVATE_DEFAULT_UBS
# 12    1682709  BTG CAYMAN 2018-05-01            -1050  PRIVATE_DEFAULT_UBS
# 13     428960  BTG CAYMAN 2018-05-01           -87000  PRIVATE_DEFAULT_UBS
# 14      46169  BTG CAYMAN 2018-05-01            -2500  PRIVATE_DEFAULT_UBS
# 15    1018742  BTG CAYMAN 2018-05-01           -11232       BD_CLIENTS_UBS
# 16     424314  BTG CAYMAN 2018-05-01             -225       BD_CLIENTS_UBS
# 17    1682709  BTG CAYMAN 2018-05-01            -1500  PRIVATE_DEFAULT_UBS
# 18    1378663  BTG CAYMAN 2018-05-01           -30000       BD_CLIENTS_UBS
# 19    1682709  BTG CAYMAN 2018-05-01             -500  PRIVATE_DEFAULT_UBS
# 20    1682709  BTG CAYMAN 2018-05-01             -180  PRIVATE_DEFAULT_UBS
# 21    1682709  BTG CAYMAN 2018-05-01             -900  PRIVATE_DEFAULT_UBS
# 22    1682709  BTG CAYMAN 2018-05-02             -350  PRIVATE_DEFAULT_UBS
# 23    1682709  BTG CAYMAN 2018-05-02             -100  PRIVATE_DEFAULT_UBS
# 33      46537  BTG CAYMAN 2018-05-02           -16000  PRIVATE_DEFAULT_UBS
# 34    1682709  BTG CAYMAN 2018-05-02            -1050  PRIVATE_DEFAULT_UBS
# 35     428960  BTG CAYMAN 2018-05-02           -87000  PRIVATE_DEFAULT_UBS
# 36    1018742  BTG CAYMAN 2018-05-02           -11232       BD_CLIENTS_UBS
# 37    1682709  BTG CAYMAN 2018-05-02            -1500  PRIVATE_DEFAULT_UBS
# 38    1378663  BTG CAYMAN 2018-05-02           -30000       BD_CLIENTS_UBS
# 39    1682709  BTG CAYMAN 2018-05-02             -500  PRIVATE_DEFAULT_UBS
# 40    1682709  BTG CAYMAN 2018-05-02             -180  PRIVATE_DEFAULT_UBS
# 41    1682709  BTG CAYMAN 2018-05-02             -900  PRIVATE_DEFAULT_UBS
# 42    1682709  BTG CAYMAN 2018-05-03             -350  PRIVATE_DEFAULT_UBS
# 43    1682709  BTG CAYMAN 2018-05-03             -100  PRIVATE_DEFAULT_UBS
# 53      46537  BTG CAYMAN 2018-05-03           -16000  PRIVATE_DEFAULT_UBS
# 54    1682709  BTG CAYMAN 2018-05-03            -1050  PRIVATE_DEFAULT_UBS
# 55     428960  BTG CAYMAN 2018-05-03           -87000  PRIVATE_DEFAULT_UBS
# 56    1018742  BTG CAYMAN 2018-05-03           -11232       BD_CLIENTS_UBS
# ..        ...         ...        ...              ...                  ...
# 495     46537  BTG CAYMAN 2018-05-30           -16000  PRIVATE_DEFAULT_UBS
# 496   1682709  BTG CAYMAN 2018-05-30             -350  PRIVATE_DEFAULT_UBS
# 497   1682709  BTG CAYMAN 2018-05-30             -700  PRIVATE_DEFAULT_UBS
# 498    428960  BTG CAYMAN 2018-05-30           -87000  PRIVATE_DEFAULT_UBS
# 499   1378663  BTG CAYMAN 2018-05-30           -40000       BD_CLIENTS_UBS
# 500   1682709  BTG CAYMAN 2018-05-30            -1500  PRIVATE_DEFAULT_UBS
# 501   1378663  BTG CAYMAN 2018-05-30            -4364       BD_CLIENTS_UBS
# 502   1378663  BTG CAYMAN 2018-05-30           -40000       BD_CLIENTS_UBS
# 503   1682709  BTG CAYMAN 2018-05-30             -500  PRIVATE_DEFAULT_UBS
# 504   1682709  BTG CAYMAN 2018-05-30             -130  PRIVATE_DEFAULT_UBS
# 505   1682709  BTG CAYMAN 2018-05-30            -1500  PRIVATE_DEFAULT_UBS
# 506   1682709  BTG CAYMAN 2018-05-30            -2500  PRIVATE_DEFAULT_UBS
# 507   1682709  BTG CAYMAN 2018-05-30            -2000  PRIVATE_DEFAULT_UBS
# 508   1682709  BTG CAYMAN 2018-05-30            -1000  PRIVATE_DEFAULT_UBS
# 509   1682709  BTG CAYMAN 2018-05-31             -350  PRIVATE_DEFAULT_UBS
# 510   1682709  BTG CAYMAN 2018-05-31             -150  PRIVATE_DEFAULT_UBS
# 520     46537  BTG CAYMAN 2018-05-31           -16000  PRIVATE_DEFAULT_UBS
# 521   1682709  BTG CAYMAN 2018-05-31             -350  PRIVATE_DEFAULT_UBS
# 522   1682709  BTG CAYMAN 2018-05-31             -700  PRIVATE_DEFAULT_UBS
# 523   1378663  BTG CAYMAN 2018-05-31           -40000       BD_CLIENTS_UBS
# 524    424314  BTG CAYMAN 2018-05-31             -385       BD_CLIENTS_UBS
# 525   1682709  BTG CAYMAN 2018-05-31            -1500  PRIVATE_DEFAULT_UBS
# 526   1378663  BTG CAYMAN 2018-05-31            -4364       BD_CLIENTS_UBS
# 527   1378663  BTG CAYMAN 2018-05-31           -40000       BD_CLIENTS_UBS
# 528   1682709  BTG CAYMAN 2018-05-31             -500  PRIVATE_DEFAULT_UBS
# 529   1682709  BTG CAYMAN 2018-05-31             -130  PRIVATE_DEFAULT_UBS
# 530   1682709  BTG CAYMAN 2018-05-31            -1000  PRIVATE_DEFAULT_UBS
# 531   1682709  BTG CAYMAN 2018-05-31            -2500  PRIVATE_DEFAULT_UBS
# 532   1682709  BTG CAYMAN 2018-05-31            -2000  PRIVATE_DEFAULT_UBS
# 533   1682709  BTG CAYMAN 2018-05-31            -1000  PRIVATE_DEFAULT_UBS
#
#       ticker currency                                             conta  \
# 0      FB US      USD               BEAVER CREEK GLOBAL FD SPC ARROBA 3
# 1    MELI US      USD               BEAVER CREEK GLOBAL FD SPC ARROBA 3
# 11   PAGS US      USD  PLATINA MULTI STRATEGY FUND - SEGREGATED PORTF A
# 12    TGT US      USD               BEAVER CREEK GLOBAL FD SPC ARROBA 3
# 13    HYG US      USD                  BOURGOGNE INTERNATIONAL FUND LTD
# 14     TX US      USD                           CMC INVESTMENT FUND LTD
# 15    BVN US      USD                           BTG PACTUAL PERU SA SAB
# 16    VCO US      USD                EUROAMERICA CORREDORES DE BOLSA SA
# 17     LE US      USD               BEAVER CREEK GLOBAL FD SPC ARROBA 3
# 18   PAGS US      USD                   EXPLORITAS ALPHA AMERICA LATINA
# 19    DRI US      USD               BEAVER CREEK GLOBAL FD SPC ARROBA 3
# 20   CSCO US      USD               BEAVER CREEK GLOBAL FD SPC ARROBA 3
# 21   CAKE US      USD               BEAVER CREEK GLOBAL FD SPC ARROBA 3
# 22     FB US      USD               BEAVER CREEK GLOBAL FD SPC ARROBA 3
# 23   MELI US      USD               BEAVER CREEK GLOBAL FD SPC ARROBA 3
# 33   PAGS US      USD  PLATINA MULTI STRATEGY FUND - SEGREGATED PORTF A
# 34    TGT US      USD               BEAVER CREEK GLOBAL FD SPC ARROBA 3
# 35    HYG US      USD                  BOURGOGNE INTERNATIONAL FUND LTD
# 36    BVN US      USD                           BTG PACTUAL PERU SA SAB
# 37     LE US      USD               BEAVER CREEK GLOBAL FD SPC ARROBA 3
# 38   PAGS US      USD                   EXPLORITAS ALPHA AMERICA LATINA
# 39    DRI US      USD               BEAVER CREEK GLOBAL FD SPC ARROBA 3
# 40   CSCO US      USD               BEAVER CREEK GLOBAL FD SPC ARROBA 3
# 41   CAKE US      USD               BEAVER CREEK GLOBAL FD SPC ARROBA 3
# 42     FB US      USD               BEAVER CREEK GLOBAL FD SPC ARROBA 3
# 43   MELI US      USD               BEAVER CREEK GLOBAL FD SPC ARROBA 3
# 53   PAGS US      USD  PLATINA MULTI STRATEGY FUND - SEGREGATED PORTF A
# 54    TGT US      USD               BEAVER CREEK GLOBAL FD SPC ARROBA 3
# 55    HYG US      USD                  BOURGOGNE INTERNATIONAL FUND LTD
# 56    BVN US      USD                           BTG PACTUAL PERU SA SAB
# ..       ...      ...                                               ...
# 495  PAGS US      USD  PLATINA MULTI STRATEGY FUND - SEGREGATED PORTF A
# 496  ORCL US      USD               BEAVER CREEK GLOBAL FD SPC ARROBA 3
# 497   TGT US      USD               BEAVER CREEK GLOBAL FD SPC ARROBA 3
# 498   HYG US      USD                  BOURGOGNE INTERNATIONAL FUND LTD
# 499   LTM US      USD                   EXPLORITAS ALPHA AMERICA LATINA
# 500    LE US      USD               BEAVER CREEK GLOBAL FD SPC ARROBA 3
# 501  MELI US      USD                   EXPLORITAS ALPHA AMERICA LATINA
# 502  PAGS US      USD                   EXPLORITAS ALPHA AMERICA LATINA
# 503   DRI US      USD               BEAVER CREEK GLOBAL FD SPC ARROBA 3
# 504  NFLX US      USD               BEAVER CREEK GLOBAL FD SPC ARROBA 3
# 505  PAGS US      USD               BEAVER CREEK GLOBAL FD SPC ARROBA 3
# 506    WU US      USD               BEAVER CREEK GLOBAL FD SPC ARROBA 3
# 507  COHU US      USD               BEAVER CREEK GLOBAL FD SPC ARROBA 3
# 508  CAKE US      USD               BEAVER CREEK GLOBAL FD SPC ARROBA 3
# 509    FB US      USD               BEAVER CREEK GLOBAL FD SPC ARROBA 3
# 510  MELI US      USD               BEAVER CREEK GLOBAL FD SPC ARROBA 3
# 520  PAGS US      USD  PLATINA MULTI STRATEGY FUND - SEGREGATED PORTF A
# 521  ORCL US      USD               BEAVER CREEK GLOBAL FD SPC ARROBA 3
# 522   TGT US      USD               BEAVER CREEK GLOBAL FD SPC ARROBA 3
# 523   LTM US      USD                   EXPLORITAS ALPHA AMERICA LATINA
# 524   SQM US      USD                EUROAMERICA CORREDORES DE BOLSA SA
# 525    LE US      USD               BEAVER CREEK GLOBAL FD SPC ARROBA 3
# 526  MELI US      USD                   EXPLORITAS ALPHA AMERICA LATINA
# 527  PAGS US      USD                   EXPLORITAS ALPHA AMERICA LATINA
# 528   DRI US      USD               BEAVER CREEK GLOBAL FD SPC ARROBA 3
# 529  NFLX US      USD               BEAVER CREEK GLOBAL FD SPC ARROBA 3
# 530  PAGS US      USD               BEAVER CREEK GLOBAL FD SPC ARROBA 3
# 531    WU US      USD               BEAVER CREEK GLOBAL FD SPC ARROBA 3
# 532  COHU US      USD               BEAVER CREEK GLOBAL FD SPC ARROBA 3
# 533  CAKE US      USD               BEAVER CREEK GLOBAL FD SPC ARROBA 3
#
#             acc  status  accrual_n_distrib  accrual_final
# 0    ubs_cayman  batido           2.350000       2.350000
# 1    ubs_cayman  batido           1.310000       1.310000
# 11   ubs_cayman  batido          19.106087      19.106087
# 12   ubs_cayman  batido           2.880000       2.880000
# 13   ubs_cayman  batido        -567.550000    -567.550000
# 14   ubs_cayman  batido           3.910000       3.910000
# 15   ubs_cayman  batido           6.970000       6.970000
# 16   ubs_cayman  batido          -2.670000      -2.670000
# 17   ubs_cayman  batido          -2.630000      -2.630000
# 18   ubs_cayman  batido          35.823913      35.823913
# 19   ubs_cayman  batido           1.800000       1.800000
# 20   ubs_cayman  batido           0.310000       0.310000
# 21   ubs_cayman  batido           1.320000       1.320000
# 22   ubs_cayman  batido           2.380000       2.380000
# 23   ubs_cayman  batido           1.290000       1.290000
# 33   ubs_cayman  batido          18.365217      18.365217
# 34   ubs_cayman  batido           2.900000       2.900000
# 35   ubs_cayman  batido        -464.200000    -464.200000
# 36   ubs_cayman  batido           6.690000       6.690000
# 37   ubs_cayman  batido          -2.470000      -2.470000
# 38   ubs_cayman  batido          34.434783      34.434783
# 39   ubs_cayman  batido           1.780000       1.780000
# 40   ubs_cayman  batido           0.300000       0.300000
# 41   ubs_cayman  batido           1.300000       1.300000
# 42   ubs_cayman  batido           2.350000       2.350000
# 43   ubs_cayman  batido           1.280000       1.280000
# 53   ubs_cayman  batido          17.617391      17.617391
# 54   ubs_cayman  batido           2.880000       2.880000
# 55   ubs_cayman  batido        -412.570000    -412.570000
# 56   ubs_cayman  batido           6.740000       6.740000
# ..          ...     ...                ...            ...
# 495  ubs_cayman  batido          22.914348      20.950261
# 496  ubs_cayman  batido           0.640000       0.640000
# 497  ubs_cayman  batido           2.000000       2.000000
# 498  ubs_cayman  batido        -154.900000    -154.900000
# 499  ubs_cayman  batido          -6.710000      -6.710000
# 500  ubs_cayman  batido          -1.660000      -1.660000
# 501  ubs_cayman  batido          51.296819      51.296819
# 502  ubs_cayman  batido          52.375652      52.375652
# 503  ubs_cayman  batido           1.730186       1.730186
# 504  ubs_cayman  batido           1.790000       1.790000
# 505  ubs_cayman  batido          22.914348       1.964087
# 506  ubs_cayman  batido           1.940000       1.940000
# 507  ubs_cayman  batido           1.890000       1.890000
# 508  ubs_cayman  batido           1.270000       1.270000
# 509  ubs_cayman  batido           2.610000       2.610000
# 510  ubs_cayman  batido           1.696389       1.696389
# 520  ubs_cayman  batido          21.995614      20.701754
# 521  ubs_cayman  batido           0.640000       0.640000
# 522  ubs_cayman  batido           1.980000       1.980000
# 523  ubs_cayman  batido         -13.330000     -13.330000
# 524  ubs_cayman  batido          -1.120000      -1.120000
# 525  ubs_cayman  batido          -1.650000      -1.650000
# 526  ubs_cayman  batido          49.353611      49.353611
# 527  ubs_cayman  batido          51.754386      51.754386
# 528  ubs_cayman  batido           1.699883       1.699883
# 529  ubs_cayman  batido           1.780000       1.780000
# 530  ubs_cayman  batido          21.995614       1.293860
# 531  ubs_cayman  batido           1.930000       1.930000
# 532  ubs_cayman  batido           1.870000       1.870000
# 533  ubs_cayman  batido           1.260000       1.260000
#
# [326 rows x 12 columns]

# %%
try:
    batimento_wm_distrib_acumulado, abertura_batidos_final_acumulado, n_batimento_wm_distrib_acumulado, n_distrib_wm_acumulado = \
                                    get_batimento_wm_distb(batimento_wm_acumulado, calypso_wm_acumulado, \
                                                           abertura_batidos_acumulado)
        
    abertura_batidos_final_acumulado = abertura_batidos_final_acumulado.rename(columns={
    'conta':'arquivo_origem',
    'conta_pb':'conta'    
}).reset_index(drop=True)
except:
    print ('calypso_month_books_acumulado provavelmente está vazio')
# Out:
# calypso_month_books_acumulado provavelmente está vazio

# %%
n_batimento_wm_distrib
# Out:
#      conta_pb       agent   data_ref  quantidade_book              book  \
# 2     1252576  BTG CAYMAN 2018-05-01             -793  BD_CLIENTS_CHILE
# 3     1252581  BTG CAYMAN 2018-05-01            -8125  BD_CLIENTS_CHILE
# 4     1252581  BTG CAYMAN 2018-05-01           -90475  BD_CLIENTS_CHILE
# 5     1252576  BTG CAYMAN 2018-05-01            -7654  BD_CLIENTS_CHILE
# 6     1252581  BTG CAYMAN 2018-05-01           -16250  BD_CLIENTS_CHILE
# 7     1252576  BTG CAYMAN 2018-05-01            -1586  BD_CLIENTS_CHILE
# 8     1252671  BTG CAYMAN 2018-05-01            -2164  BD_CLIENTS_CHILE
# 9     1252671  BTG CAYMAN 2018-05-01           -11871  BD_CLIENTS_CHILE
# 10    1252671  BTG CAYMAN 2018-05-01            -1082  BD_CLIENTS_CHILE
# 24    1252576  BTG CAYMAN 2018-05-02             -793  BD_CLIENTS_CHILE
# 25    1252581  BTG CAYMAN 2018-05-02            -8125  BD_CLIENTS_CHILE
# 26    1252581  BTG CAYMAN 2018-05-02           -90475  BD_CLIENTS_CHILE
# 27    1252576  BTG CAYMAN 2018-05-02            -7654  BD_CLIENTS_CHILE
# 28    1252581  BTG CAYMAN 2018-05-02           -16250  BD_CLIENTS_CHILE
# 29    1252576  BTG CAYMAN 2018-05-02            -1586  BD_CLIENTS_CHILE
# 30    1252671  BTG CAYMAN 2018-05-02            -2164  BD_CLIENTS_CHILE
# 31    1252671  BTG CAYMAN 2018-05-02           -11871  BD_CLIENTS_CHILE
# 32    1252671  BTG CAYMAN 2018-05-02            -1082  BD_CLIENTS_CHILE
# 44    1252576  BTG CAYMAN 2018-05-03             -793  BD_CLIENTS_CHILE
# 45    1252581  BTG CAYMAN 2018-05-03            -8125  BD_CLIENTS_CHILE
# 46    1252581  BTG CAYMAN 2018-05-03           -90475  BD_CLIENTS_CHILE
# 47    1252576  BTG CAYMAN 2018-05-03            -7654  BD_CLIENTS_CHILE
# 48    1252581  BTG CAYMAN 2018-05-03           -16250  BD_CLIENTS_CHILE
# 49    1252576  BTG CAYMAN 2018-05-03            -1586  BD_CLIENTS_CHILE
# 50    1252671  BTG CAYMAN 2018-05-03            -2164  BD_CLIENTS_CHILE
# 51    1252671  BTG CAYMAN 2018-05-03           -11871  BD_CLIENTS_CHILE
# 52    1252671  BTG CAYMAN 2018-05-03            -1082  BD_CLIENTS_CHILE
# 65    1252576  BTG CAYMAN 2018-05-04             -793  BD_CLIENTS_CHILE
# 66    1252581  BTG CAYMAN 2018-05-04            -8125  BD_CLIENTS_CHILE
# 67    1252581  BTG CAYMAN 2018-05-04           -90475  BD_CLIENTS_CHILE
# ..        ...         ...        ...              ...               ...
# 442   1252581  BTG CAYMAN 2018-05-28           -90475  BD_CLIENTS_CHILE
# 443   1252576  BTG CAYMAN 2018-05-28            -7654  BD_CLIENTS_CHILE
# 444   1252581  BTG CAYMAN 2018-05-28           -16250  BD_CLIENTS_CHILE
# 445   1252576  BTG CAYMAN 2018-05-28            -1586  BD_CLIENTS_CHILE
# 446   1252671  BTG CAYMAN 2018-05-28            -2164  BD_CLIENTS_CHILE
# 447   1252671  BTG CAYMAN 2018-05-28           -11871  BD_CLIENTS_CHILE
# 464   1252581  BTG CAYMAN 2018-05-29           -90475  BD_CLIENTS_CHILE
# 465   1252576  BTG CAYMAN 2018-05-29            -7654  BD_CLIENTS_CHILE
# 466   1252581  BTG CAYMAN 2018-05-29           -16250  BD_CLIENTS_CHILE
# 467   1252576  BTG CAYMAN 2018-05-29            -1586  BD_CLIENTS_CHILE
# 468   1252671  BTG CAYMAN 2018-05-29            -2164  BD_CLIENTS_CHILE
# 469   1252671  BTG CAYMAN 2018-05-29           -11871  BD_CLIENTS_CHILE
# 485   1252576  BTG CAYMAN 2018-05-30            -9740  BD_CLIENTS_CHILE
# 486   1252581  BTG CAYMAN 2018-05-30           -79750  BD_CLIENTS_CHILE
# 487   1252581  BTG CAYMAN 2018-05-30           -90475  BD_CLIENTS_CHILE
# 488   1252576  BTG CAYMAN 2018-05-30            -7654  BD_CLIENTS_CHILE
# 489   1252581  BTG CAYMAN 2018-05-30           -16250  BD_CLIENTS_CHILE
# 490   1252576  BTG CAYMAN 2018-05-30            -1586  BD_CLIENTS_CHILE
# 491   1252671  BTG CAYMAN 2018-05-30            -2164  BD_CLIENTS_CHILE
# 492   1252671  BTG CAYMAN 2018-05-30           -11871  BD_CLIENTS_CHILE
# 493   1252671  BTG CAYMAN 2018-05-30           -10510  BD_CLIENTS_CHILE
# 511   1252576  BTG CAYMAN 2018-05-31            -9740  BD_CLIENTS_CHILE
# 512   1252581  BTG CAYMAN 2018-05-31           -79750  BD_CLIENTS_CHILE
# 513   1252581  BTG CAYMAN 2018-05-31           -90475  BD_CLIENTS_CHILE
# 514   1252576  BTG CAYMAN 2018-05-31            -7654  BD_CLIENTS_CHILE
# 515   1252581  BTG CAYMAN 2018-05-31           -16250  BD_CLIENTS_CHILE
# 516   1252576  BTG CAYMAN 2018-05-31            -1586  BD_CLIENTS_CHILE
# 517   1252671  BTG CAYMAN 2018-05-31            -2164  BD_CLIENTS_CHILE
# 518   1252671  BTG CAYMAN 2018-05-31           -11871  BD_CLIENTS_CHILE
# 519   1252671  BTG CAYMAN 2018-05-31           -10510  BD_CLIENTS_CHILE
#
#        ticker currency                             conta  acc status  \
# 2      LTM CI      CLP     SPX FUND SPC - CANADIAN EAGLE  NaN    NaN
# 3      LTM CI      CLP  SPX FUND SPC SEGR PORT EXCLUSIVE  NaN    NaN
# 4     CMPC CI      CLP  SPX FUND SPC SEGR PORT EXCLUSIVE  NaN    NaN
# 5     CMPC CI      CLP     SPX FUND SPC - CANADIAN EAGLE  NaN    NaN
# 6    COPEC CI      CLP  SPX FUND SPC SEGR PORT EXCLUSIVE  NaN    NaN
# 7    COPEC CI      CLP     SPX FUND SPC - CANADIAN EAGLE  NaN    NaN
# 8    COPEC CI      CLP    SPX FUND SPC - SEGR PORT EAGLE  NaN    NaN
# 9     CMPC CI      CLP    SPX FUND SPC - SEGR PORT EAGLE  NaN    NaN
# 10     LTM CI      CLP    SPX FUND SPC - SEGR PORT EAGLE  NaN    NaN
# 24     LTM CI      CLP     SPX FUND SPC - CANADIAN EAGLE  NaN    NaN
# 25     LTM CI      CLP  SPX FUND SPC SEGR PORT EXCLUSIVE  NaN    NaN
# 26    CMPC CI      CLP  SPX FUND SPC SEGR PORT EXCLUSIVE  NaN    NaN
# 27    CMPC CI      CLP     SPX FUND SPC - CANADIAN EAGLE  NaN    NaN
# 28   COPEC CI      CLP  SPX FUND SPC SEGR PORT EXCLUSIVE  NaN    NaN
# 29   COPEC CI      CLP     SPX FUND SPC - CANADIAN EAGLE  NaN    NaN
# 30   COPEC CI      CLP    SPX FUND SPC - SEGR PORT EAGLE  NaN    NaN
# 31    CMPC CI      CLP    SPX FUND SPC - SEGR PORT EAGLE  NaN    NaN
# 32     LTM CI      CLP    SPX FUND SPC - SEGR PORT EAGLE  NaN    NaN
# 44     LTM CI      CLP     SPX FUND SPC - CANADIAN EAGLE  NaN    NaN
# 45     LTM CI      CLP  SPX FUND SPC SEGR PORT EXCLUSIVE  NaN    NaN
# 46    CMPC CI      CLP  SPX FUND SPC SEGR PORT EXCLUSIVE  NaN    NaN
# 47    CMPC CI      CLP     SPX FUND SPC - CANADIAN EAGLE  NaN    NaN
# 48   COPEC CI      CLP  SPX FUND SPC SEGR PORT EXCLUSIVE  NaN    NaN
# 49   COPEC CI      CLP     SPX FUND SPC - CANADIAN EAGLE  NaN    NaN
# 50   COPEC CI      CLP    SPX FUND SPC - SEGR PORT EAGLE  NaN    NaN
# 51    CMPC CI      CLP    SPX FUND SPC - SEGR PORT EAGLE  NaN    NaN
# 52     LTM CI      CLP    SPX FUND SPC - SEGR PORT EAGLE  NaN    NaN
# 65     LTM CI      CLP     SPX FUND SPC - CANADIAN EAGLE  NaN    NaN
# 66     LTM CI      CLP  SPX FUND SPC SEGR PORT EXCLUSIVE  NaN    NaN
# 67    CMPC CI      CLP  SPX FUND SPC SEGR PORT EXCLUSIVE  NaN    NaN
# ..        ...      ...                               ...  ...    ...
# 442   CMPC CI      CLP  SPX FUND SPC SEGR PORT EXCLUSIVE  NaN    NaN
# 443   CMPC CI      CLP     SPX FUND SPC - CANADIAN EAGLE  NaN    NaN
# 444  COPEC CI      CLP  SPX FUND SPC SEGR PORT EXCLUSIVE  NaN    NaN
# 445  COPEC CI      CLP     SPX FUND SPC - CANADIAN EAGLE  NaN    NaN
# 446  COPEC CI      CLP    SPX FUND SPC - SEGR PORT EAGLE  NaN    NaN
# 447   CMPC CI      CLP    SPX FUND SPC - SEGR PORT EAGLE  NaN    NaN
# 464   CMPC CI      CLP  SPX FUND SPC SEGR PORT EXCLUSIVE  NaN    NaN
# 465   CMPC CI      CLP     SPX FUND SPC - CANADIAN EAGLE  NaN    NaN
# 466  COPEC CI      CLP  SPX FUND SPC SEGR PORT EXCLUSIVE  NaN    NaN
# 467  COPEC CI      CLP     SPX FUND SPC - CANADIAN EAGLE  NaN    NaN
# 468  COPEC CI      CLP    SPX FUND SPC - SEGR PORT EAGLE  NaN    NaN
# 469   CMPC CI      CLP    SPX FUND SPC - SEGR PORT EAGLE  NaN    NaN
# 485    LTM CI      CLP     SPX FUND SPC - CANADIAN EAGLE  NaN    NaN
# 486    LTM CI      CLP  SPX FUND SPC SEGR PORT EXCLUSIVE  NaN    NaN
# 487   CMPC CI      CLP  SPX FUND SPC SEGR PORT EXCLUSIVE  NaN    NaN
# 488   CMPC CI      CLP     SPX FUND SPC - CANADIAN EAGLE  NaN    NaN
# 489  COPEC CI      CLP  SPX FUND SPC SEGR PORT EXCLUSIVE  NaN    NaN
# 490  COPEC CI      CLP     SPX FUND SPC - CANADIAN EAGLE  NaN    NaN
# 491  COPEC CI      CLP    SPX FUND SPC - SEGR PORT EAGLE  NaN    NaN
# 492   CMPC CI      CLP    SPX FUND SPC - SEGR PORT EAGLE  NaN    NaN
# 493    LTM CI      CLP    SPX FUND SPC - SEGR PORT EAGLE  NaN    NaN
# 511    LTM CI      CLP     SPX FUND SPC - CANADIAN EAGLE  NaN    NaN
# 512    LTM CI      CLP  SPX FUND SPC SEGR PORT EXCLUSIVE  NaN    NaN
# 513   CMPC CI      CLP  SPX FUND SPC SEGR PORT EXCLUSIVE  NaN    NaN
# 514   CMPC CI      CLP     SPX FUND SPC - CANADIAN EAGLE  NaN    NaN
# 515  COPEC CI      CLP  SPX FUND SPC SEGR PORT EXCLUSIVE  NaN    NaN
# 516  COPEC CI      CLP     SPX FUND SPC - CANADIAN EAGLE  NaN    NaN
# 517  COPEC CI      CLP    SPX FUND SPC - SEGR PORT EAGLE  NaN    NaN
# 518   CMPC CI      CLP    SPX FUND SPC - SEGR PORT EAGLE  NaN    NaN
# 519    LTM CI      CLP    SPX FUND SPC - SEGR PORT EAGLE  NaN    NaN
#
#      accrual_final
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 9              NaN
# 10             NaN
# 24             NaN
# 25             NaN
# 26             NaN
# 27             NaN
# 28             NaN
# 29             NaN
# 30             NaN
# 31             NaN
# 32             NaN
# 44             NaN
# 45             NaN
# 46             NaN
# 47             NaN
# 48             NaN
# 49             NaN
# 50             NaN
# 51             NaN
# 52             NaN
# 65             NaN
# 66             NaN
# 67             NaN
# ..             ...
# 442            NaN
# 443            NaN
# 444            NaN
# 445            NaN
# 446            NaN
# 447            NaN
# 464            NaN
# 465            NaN
# 466            NaN
# 467            NaN
# 468            NaN
# 469            NaN
# 485            NaN
# 486            NaN
# 487            NaN
# 488            NaN
# 489            NaN
# 490            NaN
# 491            NaN
# 492            NaN
# 493            NaN
# 511            NaN
# 512            NaN
# 513            NaN
# 514            NaN
# 515            NaN
# 516            NaN
# 517            NaN
# 518            NaN
# 519            NaN
#
# [208 rows x 11 columns]

# %%
abertura_batidos_consol = abertura_batidos.groupby(['acc', 'book', 'currency'])\
                                        .sum().reset_index().drop('quantidade_book', axis=1)

# %%
total_wm = pd.DataFrame(batimento_wm_distrib.groupby(by=['acc','book','currency']).sum()['accrual_final']).reset_index()

# %%
total_wm_calypso = abertura_batidos_consol[(abertura_batidos_consol['book'].str.contains('CLIENTS'))|\
                       (abertura_batidos_consol['book'].str.contains('PRIVATE'))].reset_index(drop=True)

# %%
total_wm
# Out:
#           acc                 book currency  accrual_final
# 0  ubs_cayman       BD_CLIENTS_UBS      USD    1366.503491
# 1  ubs_cayman  PRIVATE_DEFAULT_UBS      USD   -9138.164422

# %%
total_wm_calypso
# Out:
#           acc                 book currency  accrual_final
# 0  ubs_cayman       BD_CLIENTS_UBS      USD    1343.423491
# 1  ubs_cayman  PRIVATE_DEFAULT_UBS      USD   -9138.164422

# %%
total_wm_n_distrib = pd.merge(total_wm, total_wm_calypso, on=['acc','book','currency'], how='left')

# %%
total_wm_n_distrib['accrual_final'] = total_wm_n_distrib['accrual_final_x']-total_wm_n_distrib['accrual_final_y']

# %%
total_wm_n_distrib = total_wm_n_distrib.drop(['accrual_final_x', 'accrual_final_y'], axis=1)

# %%
total_wm_n_distrib
# Out:
#           acc                 book currency  accrual_final
# 0  ubs_cayman       BD_CLIENTS_UBS      USD   2.308000e+01
# 1  ubs_cayman  PRIVATE_DEFAULT_UBS      USD  -5.456968e-12

# %%
abertura_batidos_consol = pd.concat([abertura_batidos_consol, total_wm_n_distrib], axis=0)\
                            .groupby(by=['acc','book','currency']).sum().reset_index()

# %%
abertura_batidos_consol
# Out:
#            acc                          book currency  accrual_final
# 0        int_c          ACOES_OFFSHORE_.INTC      AUD   -2797.750000
# 1        int_c          ACOES_OFFSHORE_.INTC      MXN   -1663.570000
# 2        int_c          ACOES_OFFSHORE_.INTC      USD    1524.049791
# 3        int_c           ACOES_OFFSHORE_INTC      USD   -1959.812938
# 4        int_c           INTRADAY_PAIRS.INTC      USD    -163.723634
# 5        int_c                LOCAL_ADR_INTC      USD   -7638.912803
# 6        int_c             LOCAL_ADR_MR.INTC      USD  -12198.840416
# 7    ms_cayman               13F_COMM.CAYMAN      USD   -3452.080000
# 8    ms_cayman          13F_CONS_CYCL.CAYMAN      USD    -878.135495
# 9    ms_cayman        13F_CONS_N_CYCL.CAYMAN      USD   -1159.173843
# 10   ms_cayman             13F_ENERGY.CAYMAN      USD   -1475.577273
# 11   ms_cayman               13F_INDU.CAYMAN      USD   -4549.350000
# 12   ms_cayman               BANKS_BRASIL_RV      EUR       0.000000
# 13   ms_cayman             CHILE_CANCELATION      USD      -3.264516
# 14   ms_cayman              CHILE_DIRECIONAL      USD  -10297.610174
# 15   ms_cayman                CHILE_ISSUANCE      USD     -13.055310
# 16   ms_cayman                 CHILE_NETTING      USD    -509.790273
# 17   ms_cayman                 CO_ARB.CAYMAN      USD  122644.255846
# 18   ms_cayman                 CO_FUT.CAYMAN      USD   -4587.957000
# 19   ms_cayman               CO_PAIRS.CAYMAN      USD -136638.458845
# 20   ms_cayman                    ENERGY_ARG      USD    -112.070000
# 21   ms_cayman                        EV_IMP      USD     748.846566
# 22   ms_cayman                     EV_MEXICO      USD    1448.653950
# 23   ms_cayman          FLOW_US_NOTAS.CAYMAN      USD       9.225495
# 24   ms_cayman            FLOW_US_QQQ.CAYMAN      USD     -32.430222
# 25   ms_cayman            HDG_ABS_MEX.CAYMAN      MXN -494770.673351
# 26   ms_cayman            HDG_ABS_MEX.CAYMAN      USD   -6552.407457
# 27   ms_cayman            HDG_GLOB_EQ.CAYMAN      USD   -4493.036104
# 28   ms_cayman                       HDG_MEX      USD   -6309.032322
# 29   ms_cayman                HDG_MEX.Cayman      USD    1302.993026
# 30   ms_cayman         INTRADAY_PAIRS.CAYMAN      USD   -1655.001758
# 31   ms_cayman         LATAM_AIRLINES.CAYMAN      USD   -1507.129727
# 32   ms_cayman          LATAM_FOODBEV.CAYMAN      MXN  -20653.050000
# 33   ms_cayman           LATAM_INDICE.CAYMAN      USD    1482.239890
# 34   ms_cayman           LATAM_RETAIL.CAYMAN      EUR    -467.130000
# 35   ms_cayman           LATAM_RETAIL.CAYMAN      MXN -124244.360000
# 36   ms_cayman           LATAM_RETAIL.CAYMAN      USD   -1844.010000
# 37   ms_cayman          LATAM_TELECOM.CAYMAN      MXN  -16645.810000
# 38   ms_cayman          LATAM_TELECOM.CAYMAN      USD   -2874.945027
# 39   ms_cayman            LS_AIRLINES.CAYMAN      USD      -2.930000
# 40   ms_cayman             LS_FOODBEV.CAYMAN      USD      -9.080000
# 41   ms_cayman              LS_METALS.CAYMAN      USD   -1142.680000
# 42   ms_cayman            LS_NONBANKS.CAYMAN      USD   -6320.230000
# 43   ms_cayman                MA_TRCO.CAYMAN      USD       0.000000
# 44   ms_cayman         MEX_DIRECIONAL.CAYMAN      MXN -325950.626649
# 45   ms_cayman         MEX_DIRECIONAL.CAYMAN      USD  -75551.711578
# 46   ms_cayman            MOMENTUM_US.CAYMAN      USD    -743.607102
# 47   ms_cayman             QTS_EUROPA.CAYMAN      GBP      -1.160000
# 48   ms_cayman                 QTS_US.CAYMAN      USD    -494.390747
# 49   ms_cayman         VI_MACRO_RATES.CAYMAN      USD   -1856.800000
# 50  ubs_cayman                BD_CLIENTS_UBS      USD    1366.503491
# 51  ubs_cayman           PRIVATE_DEFAULT_UBS      USD   -9138.164422
# 52  ubs_cayman  SICAV LATAM HEDGE.CAYMAN_UBS      USD    2116.086099
# 53  ubs_cayman              TREAS_OPS.CAYMAN      MXN -891483.310000
# 54  ubs_cayman              TREAS_OPS.CAYMAN      USD   39056.994832

# %%
batimento_wm_distrib = batimento_wm_distrib.drop('accrual_n_distrib', axis=1)

# %%
abertura_batidos_consol_ajuste = abertura_batidos_consol.groupby(by=['acc', 'currency']).sum().reset_index()

# %%
'''info_emails = pd.DataFrame({
    'acc':['ms_cayman','ms_cayman','ms_cayman','ubs_cayman', 'int_c','int_c','int_c'],
    'currency':['USD','GBP','MXN','MXN','AUD','USD','MXN'],
    'accrual_final':[-152710.77,-1.07,-999326.27,-721247.90,-2492.32,-9907.02,-1482.73]
})'''
# Out:
# "info_emails = pd.DataFrame({\n    'acc':['ms_cayman','ms_cayman','ms_cayman','ubs_cayman', 'int_c','int_c','int_c'],\n    'currency':['USD','GBP','MXN','MXN','AUD','USD','MXN'],\n    'accrual_final':[-152710.77,-1.07,-999326.27,-721247.90,-2492.32,-9907.02,-1482.73]\n})"

# %%
'''info_emails = pd.DataFrame({
    'acc':['ms_cayman','ms_cayman','ms_cayman','ubs_cayman','ubs_cayman', 'int_c','int_c'],
    'currency':['USD','GBP','MXN','USD','MXN','AUD','USD'],
    'accrual_final':[-193547.92, -1.23, -410018.67,-32656.22,-747445.48,-2290.07,-2600.76]
})'''

# %%
info_emails = pd.DataFrame({
    'acc':['ms_cayman','ms_cayman','ms_cayman','ms_cayman','ubs_cayman', 'int_c','int_c','int_c'],
    'currency':['USD','EUR','GBP','MXN','MXN','AUD','USD','MXN'],
    'accrual_final':[-149037.61,-467.13,-1.16,-982264.52,-1037265.09,-2797.75,-20443.32,-1663.57]
})

# %%
info_emails
# Out:
#           acc  accrual_final currency
# 0   ms_cayman     -149037.61      USD
# 1   ms_cayman        -467.13      EUR
# 2   ms_cayman          -1.16      GBP
# 3   ms_cayman     -982264.52      MXN
# 4  ubs_cayman    -1037265.09      MXN
# 5       int_c       -2797.75      AUD
# 6       int_c      -20443.32      USD
# 7       int_c       -1663.57      MXN

# %%
ajuste = pd.merge(abertura_batidos_consol_ajuste, info_emails, on=['acc','currency'], how='left')

# %%
ajuste['multiplicador'] = ajuste['accrual_final_y']/ajuste['accrual_final_x']

# %%
ajuste = ajuste.rename(columns={
    'accrual_final_x':'accrual_final_gerado',
    'accrual_final_y':'accrual_final_email' 
}).fillna(0)

# %%
ajuste
# Out:
#           acc currency  accrual_final_gerado  accrual_final_email  \
# 0       int_c      AUD              -2797.75             -2797.75
# 1       int_c      MXN              -1663.57             -1663.57
# 2       int_c      USD             -20437.24            -20443.32
# 3   ms_cayman      EUR               -467.13              -467.13
# 4   ms_cayman      GBP                 -1.16                -1.16
# 5   ms_cayman      MXN            -982264.52           -982264.52
# 6   ms_cayman      USD            -147429.73           -149037.61
# 7  ubs_cayman      MXN            -891483.31          -1037265.09
# 8  ubs_cayman      USD              33401.42                 0.00
#
#    multiplicador
# 0       1.000000
# 1       1.000000
# 2       1.000297
# 3       1.000000
# 4       1.000000
# 5       1.000000
# 6       1.010906
# 7       1.163527
# 8       0.000000

# %%
ajuste = ajuste.drop(['accrual_final_gerado', 'accrual_final_email'], axis=1)

# %%
abertura_batidos_consol = pd.merge(abertura_batidos_consol, ajuste, on=['acc','currency'], how='left')

# %%
abertura_batidos_consol['accrual'] = abertura_batidos_consol['accrual_final']*abertura_batidos_consol['multiplicador']

# %%
abertura_batidos_consol = abertura_batidos_consol.drop(['accrual_final','multiplicador'], axis=1)

# %%
abertura_batidos_consol = abertura_batidos_consol[abertura_batidos_consol['accrual']!=0]

# %%
abertura_batidos_consol
# Out:
#            acc                    book currency       accrual
# 0        int_c    ACOES_OFFSHORE_.INTC      AUD -2.797750e+03
# 1        int_c    ACOES_OFFSHORE_.INTC      MXN -1.663570e+03
# 2        int_c    ACOES_OFFSHORE_.INTC      USD  1.524503e+03
# 3        int_c     ACOES_OFFSHORE_INTC      USD -1.960396e+03
# 4        int_c     INTRADAY_PAIRS.INTC      USD -1.637723e+02
# 5        int_c          LOCAL_ADR_INTC      USD -7.641185e+03
# 6        int_c       LOCAL_ADR_MR.INTC      USD -1.220247e+04
# 7    ms_cayman         13F_COMM.CAYMAN      USD -3.489729e+03
# 8    ms_cayman    13F_CONS_CYCL.CAYMAN      USD -8.877125e+02
# 9    ms_cayman  13F_CONS_N_CYCL.CAYMAN      USD -1.171816e+03
# 10   ms_cayman       13F_ENERGY.CAYMAN      USD -1.491670e+03
# 11   ms_cayman         13F_INDU.CAYMAN      USD -4.598966e+03
# 13   ms_cayman       CHILE_CANCELATION      USD -3.300119e+00
# 14   ms_cayman        CHILE_DIRECIONAL      USD -1.040992e+04
# 15   ms_cayman          CHILE_ISSUANCE      USD -1.319769e+01
# 16   ms_cayman           CHILE_NETTING      USD -5.153501e+02
# 17   ms_cayman           CO_ARB.CAYMAN      USD  1.239818e+05
# 18   ms_cayman           CO_FUT.CAYMAN      USD -4.637994e+03
# 19   ms_cayman         CO_PAIRS.CAYMAN      USD -1.381286e+05
# 20   ms_cayman              ENERGY_ARG      USD -1.132922e+02
# 21   ms_cayman                  EV_IMP      USD  7.570135e+02
# 22   ms_cayman               EV_MEXICO      USD  1.464453e+03
# 23   ms_cayman    FLOW_US_NOTAS.CAYMAN      USD  9.326109e+00
# 24   ms_cayman      FLOW_US_QQQ.CAYMAN      USD -3.278391e+01
# 25   ms_cayman      HDG_ABS_MEX.CAYMAN      MXN -4.947707e+05
# 26   ms_cayman      HDG_ABS_MEX.CAYMAN      USD -6.623869e+03
# 27   ms_cayman      HDG_GLOB_EQ.CAYMAN      USD -4.542038e+03
# 28   ms_cayman                 HDG_MEX      USD -6.377839e+03
# 29   ms_cayman          HDG_MEX.Cayman      USD  1.317204e+03
# 30   ms_cayman   INTRADAY_PAIRS.CAYMAN      USD -1.673051e+03
# 31   ms_cayman   LATAM_AIRLINES.CAYMAN      USD -1.523567e+03
# 32   ms_cayman    LATAM_FOODBEV.CAYMAN      MXN -2.065305e+04
# 33   ms_cayman     LATAM_INDICE.CAYMAN      USD  1.498405e+03
# 34   ms_cayman     LATAM_RETAIL.CAYMAN      EUR -4.671300e+02
# 35   ms_cayman     LATAM_RETAIL.CAYMAN      MXN -1.242444e+05
# 36   ms_cayman     LATAM_RETAIL.CAYMAN      USD -1.864121e+03
# 37   ms_cayman    LATAM_TELECOM.CAYMAN      MXN -1.664581e+04
# 38   ms_cayman    LATAM_TELECOM.CAYMAN      USD -2.906299e+03
# 39   ms_cayman      LS_AIRLINES.CAYMAN      USD -2.961955e+00
# 40   ms_cayman       LS_FOODBEV.CAYMAN      USD -9.179027e+00
# 41   ms_cayman        LS_METALS.CAYMAN      USD -1.155142e+03
# 42   ms_cayman      LS_NONBANKS.CAYMAN      USD -6.389159e+03
# 44   ms_cayman   MEX_DIRECIONAL.CAYMAN      MXN -3.259506e+05
# 45   ms_cayman   MEX_DIRECIONAL.CAYMAN      USD -7.637568e+04
# 46   ms_cayman      MOMENTUM_US.CAYMAN      USD -7.517169e+02
# 47   ms_cayman       QTS_EUROPA.CAYMAN      GBP -1.160000e+00
# 48   ms_cayman           QTS_US.CAYMAN      USD -4.997826e+02
# 49   ms_cayman   VI_MACRO_RATES.CAYMAN      USD -1.877050e+03
# 53  ubs_cayman        TREAS_OPS.CAYMAN      MXN -1.037265e+06

# %%
batimento_wm_distrib = pd.merge(batimento_wm_distrib, ajuste, on=['acc','currency'], how='left')

# %%
batimento_wm_distrib['accrual'] = batimento_wm_distrib['accrual_final']*batimento_wm_distrib['multiplicador']

# %%
batimento_wm_distrib = batimento_wm_distrib.drop(['accrual_final', 'multiplicador'], axis=1)

# %%
batimento_wm_distrib = batimento_wm_distrib[batimento_wm_distrib['accrual']!=0]

# %% [markdown]
# # Resultados

# %%
string = get_name(mes_ref, ano_ref, data, referencia = tipo)

# %%
save_path = r'\\DRIOC0231PFS\Apoio_SB\Geral\BD\Aluguel_Offshore\Arquivos diários'

# %%
if tipo == 'month':
    subfolder = mes_ref+str(ano_ref)
    final_path = save_path+'\\'+subfolder+'\\'+'consolidado'
    if os.path.isdir(save_path+'\\'+subfolder)==True:
        if os.path.isdir(save_path+'\\'+subfolder+'\\'+'consolidado')==False:
            os.mkdir(save_path+'\\'+subfolder+'\\'+'consolidado')
    else:
        os.mkdir(save_path+'\\'+subfolder)
        os.mkdir(save_path+'\\'+subfolder+'\\'+'consolidado')
else:
    subfolder = months_dict[pd.to_datetime(data).month]+str(pd.to_datetime(data).year)
    final_path = save_path+'\\'+subfolder+'\\'+data
    if os.path.isdir(save_path+'\\'+subfolder)==True:
        if os.path.isdir(save_path+'\\'+subfolder+'\\'+data)==False:
            os.mkdir(save_path+'\\'+subfolder+'\\'+data)
    else:
        os.mkdir(save_path+'\\'+subfolder)
        os.mkdir(save_path+'\\'+subfolder+'\\'+data)

# %%
final_path
# Out:
# '\\\\DRIOC0231PFS\\Apoio_SB\\Geral\\BD\\Aluguel_Offshore\\Arquivos diários\\mai2018\\consolidado'

# %%
writer = pd.ExcelWriter(final_path+'\\batimento_alguel_offshore_'+string+'.xlsx')

# %%
'''abertura_batidos_final.to_excel(writer, sheet_name = 'abertura_batidos_final')

batimento_wm_distrib.to_excel(writer, sheet_name = 'batimento_wm_distrib')

abertura_n_batidos.to_excel(writer, sheet_name = 'abertura_n_batidos')

sobra_origem.to_excel(writer, sheet_name = 'sobra_origem')

sobra_destino.to_excel(writer, sheet_name = 'sobra_destino')'''
# Out:
# "abertura_batidos_final.to_excel(writer, sheet_name = 'abertura_batidos_final')\n\nbatimento_wm_distrib.to_excel(writer, sheet_name = 'batimento_wm_distrib')\n\nabertura_n_batidos.to_excel(writer, sheet_name = 'abertura_n_batidos')\n\nsobra_origem.to_excel(writer, sheet_name = 'sobra_origem')\n\nsobra_destino.to_excel(writer, sheet_name = 'sobra_destino')"

# %%
abertura_batidos_consol.to_excel(writer, sheet_name = 'Custos Consolidados')

# %%
batimento_wm_distrib.to_excel(writer, sheet_name = 'Distrib WM')

# %%
writer.save()

# %%
writer_2 = pd.ExcelWriter(final_path+'\\batimento_alguel_offshore_sobras'+string+'.xlsx')

# %%
abertura_n_batidos.to_excel(writer_2, sheet_name = 'abertura_n_batidos')
sobra_origem.to_excel(writer_2, sheet_name = 'sobra_origem')
sobra_destino.to_excel(writer_2, sheet_name = 'sobra_destino')

# %%
writer_2.save()

# %%
abertura_batidos_final
abertura_batidos_final_email = abertura_batidos_final.groupby(['acc', 'book', 'currency', 'arquivo_origem'])\
                                        .sum().reset_index().drop('quantidade_book', axis=1)

try:
    abertura_batidos_final_acumulado
    abertura_batidos_final_acumulado_email = abertura_batidos_final_acumulado\
                                        .groupby(['acc', 'book', 'currency', 'arquivo_origem'])\
                                            .sum().reset_index().drop('quantidade_book', axis=1)
except:
    print ('calypso_month_books_acumulado provavelmente está vazio')

# %%
abertura_batidos_final_email.to_excel(writer, sheet_name = 'abertura_batidos_final_email')

# %%
n_batimento_wm_distrib[n_batimento_wm_distrib['currency']!='CLP']

# %%
pb_wm.sum()

# %%
if abertura_batidos_final_acumulado_email.dropna().shape[0]>2:
    writer_1 = pd.ExcelWriter(final_path+'\\batimento_alguel_offshore_acumulado'+string+'.xlsx')
    abertura_batidos_final_acumulado_email.to_excel(writer_1, sheet_name = 'consolidado')
    writer.save()
