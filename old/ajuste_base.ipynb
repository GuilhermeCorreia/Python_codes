# %%
import os
import sys
sys.path.append('%s/../' % os.getcwd())

# %%
# %%time
import pandas as pd
import numpy as np
import datetime

from db import queries
from db import conexao
c = conexao.Conexao()
connection = c.con

#baixa tabela
#dt_scs = c.query('select * from swapbcb_estoque')
# Out:
# Você está conectando em outro computador
# Conexao <Engine(mysql+mysqldb://guilherme:***@datascience2:3306/breakdown-fundos?charset=utf8)>
# Você está conectando em outro computador
# Conexao <Engine(mysql+mysqldb://guilherme:***@datascience2:3306/breakdown-fundos?charset=utf8)>
# Wall time: 417 ms

# %%
#informações do aquivo de SCS do bacen. Disponível em: http://www.bcb.gov.br/htms/selic/selicedital.asp?idpai=SELICOFERTA
pasta = r"C:\Users\guilherme.oliveira\OneDrive - Rio Bravo\Documents\SWAP"
arquivo=r"\db_babi2.csv"
path = pasta+arquivo
raw = pd.read_csv(path, sep=";")
raw = raw.fillna(0.0)

# %%
raw
# Out:
#          ativo nome  ultimo     fech       volume        data     ano  month
# 0       ABCP11    0       0    10.26            0  02/01/2014  2014.0    1.0
# 1       AEFI11    0     115   115.00        91043  02/01/2014  2014.0    1.0
# 2       AGCX11    0       0     0.00            0  02/01/2014  2014.0    1.0
# 3      ALMI11B    0    3110  3110.00     31129.03  02/01/2014  2014.0    1.0
# 4      BBFI11B    0    3842  3842.00        88833  02/01/2014  2014.0    1.0
# 5       BBPO11    0  104.99   104.99   1574573.34  02/01/2014  2014.0    1.0
# 6       BBRC11    0      78    78.00     53597.01  02/01/2014  2014.0    1.0
# 7       BBVJ11    0    66.8    66.80    493203.71  02/01/2014  2014.0    1.0
# 8      BCFF11B    0      91    91.00    289586.85  02/01/2014  2014.0    1.0
# 9      BMLC11B    0   114.5   114.50        72135  02/01/2014  2014.0    1.0
# 10      BPFF11    0      80    80.00    131978.82  02/01/2014  2014.0    1.0
# ...

# %%
raw.dtypes
# Out:
# ativo      object
# nome       object
# ultimo     object
# fech      float64
# volume     object
# data       object
# ano       float64
# month     float64
# dtype: object

# %%
raw['data']=pd.to_datetime(raw['data'], format='%d/%m/%Y')
#raw['ultimo']=raw['ultimo'].astype(float)
raw['fech']=raw['fech'].astype(float)
#raw['volume']=raw['volume'].astype(float)
raw['ano']=raw['ano'].astype(int)
raw['mes']=raw['month'].astype(int)

# %%
raw.dtypes
# Out:
# ativo             object
# nome              object
# ultimo            object
# fech             float64
# volume            object
# data      datetime64[ns]
# ano                int32
# month            float64
# mes                int32
# dtype: object

# %%
rawdb=raw[['comunicado','date','codigo','data_inicio_contrato','data_vencimento','prazo_dias_corridos','qtd_contratos_lancados',
          'qtd_negocios_aceitos','tx_nominal','tx_linear','serie']].copy()

# %%
rawdb
# Out:
#       comunicado       date codigo data_inicio_contrato data_vencimento  \
# 0          16294 2007-11-27    SCS           2007-12-03      2008-04-01
# 1          16294 2007-11-27    SCS           2007-12-03      2008-10-01
# 2          16294 2007-11-27    SCS           2007-12-03      2009-04-01
# 3          16294 2007-11-27    SCS           2007-12-03      2010-01-04
# 4          16376 2007-12-21    SCS           2008-01-02      2008-04-01
# 5          16376 2007-12-21    SCS           2008-01-02      2008-10-01
# 6          16376 2007-12-21    SCS           2008-01-02      2009-04-01
# 7          16376 2007-12-21    SCS           2008-01-02      2010-01-04
# 8          16475 2008-01-30    SCS           2008-02-01      2008-05-02
# 9          16475 2008-01-30    SCS           2008-02-01      2008-11-03
# 10         16475 2008-01-30    SCS           2008-02-01      2009-07-01
# 11         16475 2008-01-30    SCS           2008-02-01      2010-04-01
# ...

# %%
rawdb.to_sql(con=connection, name='swapbcb_estoque', if_exists='replace', index=False)
