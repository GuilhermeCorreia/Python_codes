# %%
import pandas as pd
import numpy as np
import datetime
import os
import sys
sys.path.append('%s/../' % os.getcwd())

from helper import feriados
from db import conexao
c = conexao.Conexao()
connection = c.con
from ajuste_dap import *

arcv = 'N:\MAP\Guilherme\Planilhas\dap.xlsx'
# %matplotlib inline
# Out:
# Você está conectando em outro computador
# Conexao <Engine(mysql+mysqldb://guilherme:***@datascience2:3306/breakdown-fundos?charset=utf8)>

# %%
vencimento = pd.to_datetime('2018-08-15')

# %%
df = Ajustes_dap(arcv).result()
tickers = Ajustes_dap(arcv).tickers(df)

# %%
pvt=interpol_juros_nominal(df, vencimento, tickers)

# %%
pvt.plot(figsize=(18, 10))
