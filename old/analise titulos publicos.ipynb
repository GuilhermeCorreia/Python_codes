# %%
import os
import sys
sys.path.append('%s/../' % os.getcwd())

import pandas as pd
import numpy as np
import datetime

from helper import feriados
from db import conexao
c = conexao.Conexao()
connection = c.con

import formulas_tb as tb
from formulas_aux import dict_meses
# Out:
# Você está conectando em outro computador
# Conexao <Engine(mysql+mysqldb://guilherme:***@datascience2:3306/breakdown-fundos?charset=utf8)>

# %%
df_table = c.query('select * from map_rf_cmarkets')
# Out:
# select * from map_rf_cmarkets

# %% [markdown]
# # Primeira Parte: Duration dos títulos abertos - anbima

# %% [markdown]
# http://www.anbima.com.br/vna/

# %%
data=pd.to_datetime(datetime.date.today())
dict_tp={
    'LFT':0.0,
    'LTN':0.0,
    'NTN-B':0.06,
    'NTN-C':0.06,
    'NTN-F':0.06
}
dict_vna={
    'NTN-B':3000.006193,
    'NTN-C':3505.867748,
    'LFT':9026.492562,
    'LTN':1.0,
    'NTN-F':1.0
}

# %%
df=df_table[df_table['periodo']=='anbima'].copy()
df=df[df['data']==df['data'].max()]
df=df[['titulo','vencimento','compra','venda','tx_indicativa']].reset_index(drop=True)

df['cupom']=[dict_tp[df['titulo'][i]] for i in range(0,len(df))]
df['vna']=[dict_vna[df['titulo'][i]] for i in range(0,len(df))]

feriados = list(feriados.lista())
df['data_atual']=data

df['pu']=[tb.titulos(data,df['vencimento'][i],df['tx_indicativa'][i]/100,'pu',df['cupom'][i],
                  vna=df['vna'][i]) for i in range(0,len(df))]

df['mod']=[tb.titulos(data,df['vencimento'][i],df['tx_indicativa'][i]/100,'mod',
                   df['cupom'][i],vna=df['vna'][i]) for i in range(0,len(df))]


df
# Out:
#    titulo vencimento   compra    venda  tx_indicativa  cupom          vna  \
# 0     LFT 2017-09-07   0.0000   0.0000         0.0000   0.00  9026.492562
# 1     LFT 2018-03-01   0.0000   0.0000         0.0022   0.00  9026.492562
# 2     LFT 2018-09-01   0.0000   0.0000         0.0017   0.00  9026.492562
# 3     LFT 2019-03-01   0.0000   0.0000         0.0039   0.00  9026.492562
# 4     LFT 2020-03-01   0.0000   0.0000         0.0095   0.00  9026.492562
# 5     LFT 2020-09-01   0.0000   0.0000         0.0103   0.00  9026.492562
# 6     LFT 2021-03-01   0.0000   0.0000         0.0118   0.00  9026.492562
# 7     LFT 2021-09-01   0.0000   0.0000         0.0119   0.00  9026.492562
# 8     LFT 2022-03-01   0.0000   0.0000         0.0120   0.00  9026.492562
# 9     LFT 2022-09-01   0.0000   0.0000         0.0120   0.00  9026.492562
# 10    LFT 2023-03-01   0.0000   0.0000         0.0119   0.00  9026.492562
# 11    LFT 2023-09-01   0.0000   0.0000         0.0119   0.00  9026.492562
# ...

# %% [markdown]
# # Segunda Parte - Carteira fundos Rio Bravo

# %%
fundos = tb.DurationFundos(data,dict_tp,dict_vna).duration_carteiras(data,dict_tp,dict_vna)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-1e3a568326aa> in <module>()
# ----> 1 fundos = tb.DurationFundos().duration_carteiras(data,dict_tp,dict_vna)
#
# TypeError: __init__() takes exactly 4 arguments (1 given)

# %%
fundos['cupom']=[dict_tp[fundos['classe_ativo'][i]] for i in range(0,len(fundos))]
fundos['vna']=[dict_vna[fundos['classe_ativo'][i]] for i in range(0,len(fundos))]
fundos['mod']=[titulos(fundos['date'][i],fundos['vencimento'][i],fundos['pu'][i],'mod',fundos['cupom'][i],vna=fundos['vna'][i]) 
                 for i in range(0,len(fundos))]


dict_pl={
    "RIO BRAVO APOLLO FIM":48049518.00,
    "RIO BRAVO JUROS MASTER FI RF":24774574.00,
    "RIO BRAVO PREVIDENCIA FIM":17845756.00
}
fundos['pct_mod']=[fundos['posicao_atual'][i]/dict_pl[fundos['fundo'][i]]*fundos['mod'][i] for i in range(0,len(fundos))]

# %%
fundos[['fundo','mod','pct_mod']].groupby(by='fundo').sum()
