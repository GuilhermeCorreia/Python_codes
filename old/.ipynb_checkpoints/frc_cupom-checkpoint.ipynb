# %%
# %%time
# %load_ext autoreload
# %autoreload 2

import os
import sys
sys.path.append('%s/../' % os.getcwd())

import datetime
import pandas as pd
import numpy as np

from db import conexao
c = conexao.Conexao()
connection = c.con
import leitor_frc as ip


# %matplotlib inline
# Out:
# Você está conectando em outro computador
# Conexao <Engine(mysql+mysqldb://guilherme:***@datascience2:3306/breakdown-fundos?charset=utf8)>
# Wall time: 13.7 s

# %%
preco_frc = c.query('select codigo, date, ticker, sequencia_vencimento_futuro, preabe,premin, premax, '\
                    'premed,data_limite_negociacao,'\
                        'preult, cotacao_ajuste, data_liquidacao_financeira from assets_precofuturo where codigo="FRC"')
# Out:
# select codigo, date, ticker, sequencia_vencimento_futuro, preabe,premin, premax, premed,data_limite_negociacao,preult, cotacao_ajuste, data_liquidacao_financeira from assets_precofuturo where codigo="FRC"

# %%
tb_scs = c.query('select * from assets_precofuturo where codigo="SCS" or codigo="SCC" '\
                 'and tipo_serie="*" '\
                 'and date>="2004-01-01"')
# Out:
# select * from assets_precofuturo where codigo="SCS" or codigo="SCC" and tipo_serie="*" and date>="2004-01-01"

# %%
lst_dias=()

# %%
# %%time
df, lst_nomes, lst_desloc = ip.TaxasHistoricas(preco_frc,lst_dias).ajuste_dados()
# Out:
# ['Dias 46 menor que o minimo. Deslocamento de 23.0 dias']
# ['Dias 46 menor que o minimo. Deslocamento de 23.0 dias']
# Wall time: 1min 20s

# %%
# %%time
estoque_aberto, estoque_atual = ip.estoque_swap(tb_scs).contratos_abertos()
cct_hist=ip.estoque_swap(tb_scs).cct_hist()
# Out:
# Wall time: 485 ms

# %%
estoque_atual.to_excel("estoque_swaps.xlsx")

# %%
cp=df[pd.to_datetime(df.index)>pd.to_datetime('2016-1-1')]

# %%
cp[lst_nomes].plot(figsize=(18, 10))
