# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.append('%s/../' % os.getcwd())

import datetime
import pandas as pd
import numpy as np

from db import conexao
c = conexao.Conexao()
connection = c.con

import formulas_aux as fa
import formulas_interpol as ip

# %matplotlib inline
# Out:
# Você está conectando em outro computador
# Conexao <Engine(mysql+mysqldb://guilherme:***@datascience2:3306/breakdown-fundos?charset=utf8)>

# %%
# %%time
# Faz os queries de FRC e DDI. Eles estão em tabelas diferentes para poder fazer um merge depois e pegar o DDI de primeiro
# vencimento para cada dia de FRC. Assim, eu posso depois ajustar a quantidade de dias úteis em cada contrato

preco_frc = c.query('select codigo, date, ticker, sequencia_vencimento_futuro, preabe,premin, premax, premed,data_limite_negociacao,'\
                        'preult, cotacao_ajuste, data_liquidacao_financeira from assets_precofuturo where codigo="FRC" and tipo_serie="*"'\
                    'and date>="2004-01-01"')
# Out:
# select codigo, date, ticker, sequencia_vencimento_futuro, preabe,premin, premax, premed,data_limite_negociacao,preult, cotacao_ajuste, data_liquidacao_financeira from assets_precofuturo where codigo="FRC" and tipo_serie="*"and date>="2004-01-01"
# Wall time: 45 s

# %%
# %%time
preco_frc = preco_frc.copy()
preco_frc['date'] = pd.to_datetime(preco_frc['date'])
preco_frc['data_limite_negociacao'] = pd.to_datetime(preco_frc['data_limite_negociacao'])
preco_frc['data_liquidacao_financeira'] = pd.to_datetime(preco_frc['data_liquidacao_financeira'])

preco_frc['qtd_limt'] = (pd.to_timedelta(preco_frc['data_limite_negociacao'])-pd.to_timedelta(preco_frc['date'])).dt.days/360
preco_frc['qtd_liqd'] = (pd.to_timedelta(preco_frc['data_liquidacao_financeira'])-pd.to_timedelta(preco_frc['date'])).dt.days/360




preco_fut = preco_frc.drop_duplicates(subset=['date','sequencia_vencimento_futuro']).sort_values(by=['sequencia_vencimento_futuro','date']).reset_index(drop=True)
preco_fut = preco_fut[['date','ticker','sequencia_vencimento_futuro','cotacao_ajuste','qtd_limt','data_limite_negociacao',
                      'qtd_liqd','data_liquidacao_financeira']]


qt_dias = preco_fut[preco_fut['date']==preco_fut['date'].max()].reset_index().copy()
qt_dias['hoje']=pd.to_datetime(datetime.date.today())
qt_dias['liq']=(pd.to_timedelta(qt_dias['data_liquidacao_financeira'])-pd.to_timedelta(qt_dias['hoje'])).dt.days/360

preco_fut = pd.merge(preco_fut, qt_dias[['sequencia_vencimento_futuro','liq']], how='left', on='sequencia_vencimento_futuro')
# Out:
# Wall time: 6.14 s

# %%
amp = 1.5
janela = 60

# %%
# %%time
pvt = pd.pivot_table(preco_fut, values=['cotacao_ajuste','qtd_liqd', 'liq'],
                     index='date', columns='sequencia_vencimento_futuro')

pvt['cotacao_ajuste']= np.where(pvt['cotacao_ajuste']==0,np.nan,pvt['cotacao_ajuste'])
pvt = pvt.fillna(method='ffill')
pvt['cotacao_ajuste']=pvt['cotacao_ajuste']/10000

#gera as novas variáveis
for i in range(1,8):
    pvt['pct_ajuste_{0}'.format(i)] = float(len(pvt[pvt['liq'][i]<pvt['qtd_liqd'][i]]))/float(len(pvt['liq']))
    pvt['max_days_{0}'.format(i)]=(pvt['liq'][i]-pvt['qtd_liqd'][i]).max()*360
    
for i in range(1,8):
    pvt['preco_ajustado_{0}'.format(i)]=np.where(pvt['liq'][i]>pvt['qtd_liqd'][i],ip.interpol(pvt['cotacao_ajuste'][i],
                                                                                             pvt['qtd_liqd'][i],pvt['cotacao_ajuste'][i+1], 
                                                                                             pvt['qtd_liqd'][i+1],pvt['liq'][i]),
                                                pvt['cotacao_ajuste'][i])
    pvt['preco_ajustado_{0}_stdevp'.format(i)]=pvt[['preco_ajustado_{0}'.format(i)]]+amp*pd.DataFrame.rolling(pvt[['preco_ajustado_{0}'.format(i)]], window=janela).std()
    pvt['preco_ajustado_{0}_stdevn'.format(i)]=pvt[['preco_ajustado_{0}'.format(i)]]-amp*pd.DataFrame.rolling(pvt[['preco_ajustado_{0}'.format(i)]], window=janela).std()

    
for i in range(1,7):
    pvt['inclinacao_{0}'.format(i)]=(pvt['preco_ajustado_{0}'.format(i+1)]-pvt['preco_ajustado_{0}'.format(i)])
    pvt['inclinacao_{0}_stdevp'.format(i)]=pvt[['inclinacao_{0}'.format(i)]]+amp*pd.DataFrame.rolling(pvt[['inclinacao_{0}'.format(i)]], window=janela).std()
    pvt['inclinacao_{0}_stdevn'.format(i)]=pvt[['inclinacao_{0}'.format(i)]]-amp*pd.DataFrame.rolling(pvt[['inclinacao_{0}'.format(i)]], window=janela).std()
# Traz as informações sobre os ajustes!
day=pvt[['pct_ajuste_1','max_days_1','pct_ajuste_2','max_days_2','pct_ajuste_3','max_days_3','pct_ajuste_4','max_days_4',
 'pct_ajuste_5','max_days_5','pct_ajuste_6','max_days_6','pct_ajuste_7','max_days_7']].tail(1)
# Out:
# Wall time: 313 ms

# %%
pvt[['preco_ajustado_1','preco_ajustado_2','preco_ajustado_3', 'preco_ajustado_4',
     'preco_ajustado_5']].plot(figsize=(18, 10))

# %%
pvt[['inclinacao_1','inclinacao_2','inclinacao_3', 'inclinacao_4',
     'inclinacao_5']].plot(figsize=(18, 10))

# %%
i=1

# %%
pvt[['preco_ajustado_{0}'.format(i),'preco_ajustado_{0}_stdevp'.format(i),'preco_ajustado_{0}_stdevn'.format(i)]].plot(figsize=(18, 10))

# %%
dfdia = pvt.tail(1)
dfhist=pvt[['preco_ajustado_1','preco_ajustado_2','preco_ajustado_3', 'preco_ajustado_4',
     'preco_ajustado_5','preco_ajustado_6','preco_ajustado_7']]

# %%
dfdia.to_excel('dados_dia.xlsx')
dfhist.to_excel('dados_hist.xlsx')
