# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
sys.path.append('%s/../' % os.getcwd())

import datetime
import pandas as pd
import numpy as np
import getpass

# %%
path = r'C:\Users\correigu\OneDrive - Banco BTG Pactual S.A\Desktop\MIFIDII-DATABASE-2018-10-15-14-00-05.csv'

# %%
df = pd.read_csv(path, sep='\t')
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-5-e47d6d1d9212> in <module>()
# ----> 1 df = pd.read_csv(path, sep='\t')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
# ...

# %%
df.to_excel('MIFIDII-DATABASE-2018-09-20-15-18-44.xlsx')

# %%
file_1 = r'\Book1.xlsx'
file_2 =r'\Fevreiro.xlsx'

# %%
df = pd.read_excel(path+file_1)

# %%
dt = pd.read_excel(path+file_2)

# %%
dt = dt.rename(columns={'Trade_Date':'TRADE_DATE'})

# %%
dt['Titulo'] = dt['Titulo'].str.strip()

# %%
df_1 = df.drop(['Opcao','B/C'], axis=1).copy()
dt_1 = dt.drop(['Opcao','B/C'], axis=1).copy()

# %%
final = pd.merge(df, dt, on=['TRADE_DATE','Op','Titulo','Cliente','Quantidade','Preço','Bruto','Liquido'], how='left')

# %%
final = final.drop_duplicates().reset_index(drop=True)

# %%
final[final['Operador_y'].isnull()==True]
# Out:
#       TRADE_DATE       Op  Titulo  Opcao_x B/C_x Operador_x  Cliente  \
# 1585  2018-02-01   Vendas  ENGI11      NaN     C         SB   112471
# 1586  2018-02-01   Vendas  ENGI11      NaN     C         SB   112470
# 1590  2018-02-01   Vendas  ENGI11      NaN     C         SB   112471
# 1592  2018-02-01   Vendas  ENGI11      NaN     C         SB   112471
# 1623  2018-02-01   Vendas  GBIO33      NaN     C         SB   408432
# 1624  2018-02-01   Vendas  GBIO33      NaN     C         SB   408432
# 1625  2018-02-01   Vendas  GBIO33      NaN     C         SB   408432
# 1639  2018-02-01   Vendas  GBIO33      NaN     C         SB   408432
# 1640  2018-02-01   Vendas  GBIO33      NaN     C         SB   408432
# 1654  2018-02-01   Vendas  GBIO33      NaN     C         SB   408432
# 1655  2018-02-01   Vendas  GBIO33      NaN     C         SB   408432
# 1656  2018-02-01   Vendas  GBIO33      NaN     C         SB   408432
# 1671  2018-02-01   Vendas  GBIO33      NaN     C         SB   408432
# ...
