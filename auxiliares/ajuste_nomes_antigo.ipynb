# %%
import os
import sys
sys.path.append('%s/../' % os.getcwd())

# %%
import datetime
import pandas as pd
import numpy as np
import getpass
import PyPDF2

# %%
path = r'C:\Users\correigu\OneDrive - Banco BTG Pactual S.A\Desktop\salva_10\salva_29'

# %%
'LoanFeeSummary'
# Out:
# 'LoanFeeSummary'

# %%
os.listdir(path)
# Out:
# ['BillingUSEmail.MCLBTGPA(13260001).zip',
#  'BillingUSEmail.MCLBTGPA(13268851).zip',
#  'BillingUSEmail.MCLBTGPA(13276151).zip',
#  'BillingUSEmail.MCLBTGPA(13284651).zip',
#  'BillingUSEmail.MCLBTGPA(13293289).zip',
#  'BillingUSEmail.MCLBTGPA(13301246).zip',
#  'BillingUSEmail.MCLBTGPA(13309748).zip',
#  'BillingUSEmail.MCLBTGPA(13317766).zip',
#  'BillingUSEmail.MCLBTGPA(13325808).zip',
#  'BillingUSEmail.MCLBTGPA(13334453).zip',
#  'BillingUSEmail.MCLBTGPA(13342679).zip',
#  'BillingUSEmail.MCLBTGPA(13351163).zip',
#  'BillingUSEmail.MCLBTGPA(13359591).zip',
#  'BillingUSEmail.MCLBTGPA(13367298).zip',
#  'BillingUSEmail.MCLBTGPA(13376216).zip',
#  'BillingUSEmail.MCLBTGPA(13383840).zip',
#  'BillingUSEmail.MCLBTGPA(13392049).zip',
#  'BillingUSEmail.MCLBTGPA(13400266).zip',
#  'BillingUSEmail.MCLBTGPA(13408450).zip',
#  'BillingUSEmail.MCLBTGPA(13417241).zip',
#  'BillingUSEmail.MCLBTGPA(13425586).zip',
#  'BillingUSEmail.MCLBTGPA(13426924).zip',
# ...

# %%
'''for file in os.listdir(path):
    os.rename(path+'\\'+file, path+'\\'+file[:-4])'''

# %%
for file in os.listdir(path):
    if len(os.listdir(path+'\\'+file))>2:
        for arquivo in os.listdir(path+'\\'+file):
            if ('.PDF' in arquivo)|('.pdf' in arquivo):
                fileReader = PyPDF2.PdfFileReader(path+'\\'+file+'\\'+arquivo)
                pageObj = fileReader.getPage(0)
                for i in range(11,14):
                    data = pd.DataFrame(pageObj.extractText().split()).iloc[i][0]
                    if '/' in data:
                        #data = pd.to_datetime(data, format='%m/%d/%Y')
                        data = str(pd.to_datetime(data[-14:-4], format = '%m/%d/%Y')).split()[0]
                        #print (str(pd.to_datetime(data[-14:-4], format = '%m/%d/%Y')).split()[0])
                
                        for arquivo in os.listdir(path+'\\'+file):
                            if ('StockLoanFee' in arquivo)&(('.csv' in arquivo)|('.CSV' in arquivo)):
                                #print(str(data).split())
                                #print(data)
                                os.rename(path+'\\'+file+'\\'+arquivo, path+'\\'+file+'\\'+str(data).split()[0]+'.csv')

# %%
for pasta in os.listdir(path):
    for file in os.listdir(path+'\\'+pasta):
        if '2018-' in file:
            
            try:
                os.rename(path+'\\'+pasta+'\\'+file, path+'\\'+file)
            except:
                continue

# %%
for file in os.listdir(path):
    if '.csv' in file:
        os.rename(path+'\\'+file, path+'\\Ajuste - ' + file)

# %%
teste = r'C:\Users\correigu\OneDrive - Banco BTG Pactual S.A\Desktop\salva_10\salva_29\BillingUSEmail.MCLBTGPA(14067558)\DailyStockLoanFeeSummaryNew.RRBTGPRI.PDF'

# %%
fileReader = PyPDF2.PdfFileReader(teste)
pageObj = fileReader.getPage(0)

# %%
pd.DataFrame(pageObj.extractText().split())
# Out:
#                                                      0
# 0                                                  UBS
# 1                                           Securities
# 2                                             LLCPrime
# 3                                         Services1285
# 4                                               Avenue
# 5                                                   of
# 6                                                  the
# 7                                          AmericasNew
# 8                                              YorkNY,
# 9          USA10019DailyStockLoanFeeSummaryNewRRBTGPRI
# 10                                                   -
# 11                                                 BTG
# 12                             Principal03/07/2018Base
# 13                                                CCY:
# 14                                                 USD
# 15                                              Report
# ...

# %%
for file in os.listdir(path):
    if 'INT C' in file:
        try:
            intc
        except:
            intc = pd.read_excel(path+ '\\' + file)
        else:
            intc_1 = pd.read_excel(path + '\\' + file)
            intc = pd.concat([intc, intc_1], axis=0)
            
    else:
        try:
            cayman
        except:
            cayman = pd.read_excel(path + '\\' + file)
        else:
            cayman_1 = pd.read_excel(path + '\\' + file)
            cayman = pd.concat([cayman, cayman_1], axis=0)

# %%
intc['acc'] = 'INT C'

# %%
cayman['acc'] = 'Cayman'

# %%
cayman
# Out:
#    Position Date Ticker Corretoras             Asset Description  \
# 0     01/03/2018            FXI US                     038CDBD08
# 1     01/03/2018            FXI US                     038CDBD08
# 2     01/03/2018           BSMX US                     038CDBD08
# 3     01/03/2018            AMX US                     038CDBD08
# 4     01/03/2018            ASR US                     038CDBD08
# 5     01/03/2018           AMXL MM                     038CDBD08
# 6     01/03/2018           PAGS US                     038CDBD08
# 7     01/03/2018           PAGS US                     038CDBD08
# 8     01/03/2018            PAC US                     038CDBD08
# 9     01/03/2018            EWZ US                     038CDBD08
# 10    01/03/2018            EWZ US                     038CDBD08
# 11    01/03/2018            KOF US                     038CDBD08
# 12    01/03/2018       GFNORTEO MM                     038CDBD08
# ...

# %%
consol = pd.concat([intc, cayman], axis = 0).reset_index(drop=True)

# %%
consol
# Out:
#       Account Name             Asset Description Currency  Daily Loan Cost  \
# 0              NaN      ADR.BAK US(Equity.BRKM5)      USD         2.695890
# 1              NaN    ADR.PBR/A US(Equity.PETR4)      USD         0.660000
# 2              NaN      ADR.BAK US(Equity.BRKM5)      USD         3.454110
# 3              NaN                 Equity.EWZ US      USD         0.220000
# 4              NaN      ADR.CBD US(Equity.PCAR4)      USD         0.910000
# 5              NaN     ADR.ITUB US(Equity.ITUB4)      USD         0.660000
# 6              NaN                 Equity.FMG AU      AUD        77.100000
# 7              NaN      ADR.VIV US(Equity.VIVT4)      USD         0.600000
# 8              NaN      ADR.BAK US(Equity.BRKM5)      USD         2.587826
# 9              NaN    ADR.PBR/A US(Equity.PETR4)      USD         0.680000
# 10             NaN      ADR.BAK US(Equity.BRKM5)      USD         2.992174
# ...

# %%
consol.dtypes
# Out:
# Account Name         float64
# Asset Description     object
# Currency              object
# Daily Loan Cost      float64
# Institution           object
# Operator              object
# Position Date         object
# Sedol                 object
# Shares Quantity        int64
# Ticker Corretoras     object
# acc                   object
# dtype: object

# %%
consol['Position Date'] = pd.to_datetime(consol['Position Date'])

# %%
(consol[consol['Position Date'].dt.month == 4].reset_index(drop=True)).groupby(by=[\
    'acc', 'Institution', 'Currency']).sum()
# Out:
#                                      Account Name  Daily Loan Cost  \
# acc    Institution         Currency
# Cayman MORGAN STANLEY & CO CAD                NaN         0.000000
#                            EUR                NaN         0.000000
#                            GBP                NaN        -0.430000
#                            MXN                NaN   -434365.380000
#                            USD                NaN    -70989.840000
#        UBS SECURITIES LLC  MXN                NaN   -314284.510000
#                            USD                NaN      2387.214629
# INT C  MORGAN STANLEY & CO AUD                NaN      1105.360000
#                            MXN                NaN       719.220000
#                            USD                NaN      5000.240000
#
#                                      Shares Quantity
# acc    Institution         Currency
# Cayman MORGAN STANLEY & CO CAD              -1248166
# ...

# %%
consol.to_excel('batimento_abril.xlsx')
