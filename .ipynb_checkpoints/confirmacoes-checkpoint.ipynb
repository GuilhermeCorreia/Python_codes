# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
sys.path.append('%s/../' % os.getcwd())

import datetime
import pandas as pd
import numpy as np
import getpass

import aux_emails as email

# %% [markdown]
# ## Abaixo você coloca a pasta em que salvou o arquivo do Fidessa!

# %%
#O getpass no final é pra ficar com o seu nome no caminho. Você também pode colocar hardcoded!!
pasta = r'C:\Users\%s\OneDrive - Banco BTG Pactual S.A\Documents\trades_fidessa' % getpass.getuser()

# %%
email_saida = 'guilherme.correia@btgpactual.com'

# %%
df = pd.read_csv(pasta+'\\'+'fidessa 06-12.csv')

# %%
def salva_excel(cliente, df, td):
    out_path = pasta+'\%s TD %s.xlsx' % (cliente, td)
    
    #print('Você está salvando o arquivo %s') % out_path
    
    writer = pd.ExcelWriter(out_path , engine='xlsxwriter')
    ndf.to_excel(writer, sheet_name='Planilha1', index=False)
    writer.save()
    
    #print ('Arquivo salvo no local indicado')
    return out_path, cliente, td
    
def get_gap(df):
    #print ('Gerando confirmação da GAP')
    ndf = df[df['Client/Book']=='GAP_PRUDENTIAL']

    ndf['Time']=ndf['Trade Date'].str.split().str[1]

    td = pd.to_datetime(ndf['Trade Date'].str.split().str[0].drop_duplicates().reset_index(drop=True)[0], 
                   format='%Y%m%d')

    td = str(td.month)+'-'+str(td.day)

    ndf['Order #'] = 6141811

    ndf = ndf[['Order #', 'Time', 'Client/Book', ndf.columns[9], 'Symbol', 'Volume', 'AvgPrc', 
               'Gross consideration','Comm rate', 'Market charges total', 
               'Settlement consideration']].reset_index(drop=True)

    ndf.columns = ['Order #', 'Time','Client', 'B/S', 'Stock', 'Exec Qty', 'Avg Price', 'Financial', 
                   'Comission', 'Fees', 'Net Amount']
    #print ('DataFrame da confirmação gerado')
    ndf
    
    return ndf, td

def get_spx(df):
    #print('Gerando confirmação da SPX')
    ndf = df[df['Client/Book'].str.contains("SPX")].reset_index(drop=True)

    ndf['trade_date'] = pd.to_datetime(ndf['Trade Date'].str.split().str[0], format='%Y%m%d')
    ndf['settlement_date'] = pd.to_datetime(ndf['Value date'], format='%Y%m%d')
    td = pd.to_datetime(ndf['Trade Date'].str.split().str[0].drop_duplicates().reset_index(drop=True)[0], 
                       format='%Y%m%d')
    td = str(td.month)+'-'+str(td.day)
    
    ndf = ndf[['trade_date', 'settlement_date', ndf.columns[9], 'Symbol', 'Isin code', 'Volume', 'AvgPrc',
        'Gross consideration', 'Comm rate', 'Market charges total', 'Settlement consideration', 'Fund ID']]

    ndf['Unnamed: 9'] = np.where(ndf['Unnamed: 9']=='B', 'BUY', 'SELL')
    ndf['Settlement consideration'] = np.where(ndf['Unnamed: 9']=='BUY', -1*ndf['Settlement consideration'],
                                              ndf['Settlement consideration'])

    ndf.columns=['T/D', 'S/D', 'Side', 'Ticker', 'ISIN', 'Shares', 'Price', 'Principal', 'Commission',
                'SEC Fee', 'Net Amount', 'Settlement Account']
    
    #print ('DataFrame da confirmação gerado')
    ndf
    
    return ndf, td


def get_asset(df, cliente):
    
    #print ('Gerando confirmação da %s') % cliente

    ndf = df[df['Client/Book'].str.contains(cliente)].reset_index(drop=True).copy()

    ndf['trade_date'] = pd.to_datetime(ndf['Trade Date'].str.split().str[0], format='%Y%m%d')
    ndf['settlement_date'] = pd.to_datetime(ndf['Value date'], format='%Y%m%d')
    td = pd.to_datetime(ndf['Trade Date'].str.split().str[0].drop_duplicates().reset_index(drop=True)[0], 
                       format='%Y%m%d')
    td = str(td.month)+'-'+str(td.day)

    ndf['CUSIP']=' '
    ndf['SEDOL']=' '
    ndf['STRIKE PRICE']=' '
    ndf['EXPIRY DATE']=' '
    ndf['TRADE TYPE']='EQUITY'

    ndf['COUNTERPARTY']=np.where(ndf['Dealt currency']=='MXN', 'BTG PACTUAL CASA DE BOLSA SA DE CV', 'BTG PACTUAL US CAPITAL LLC')
    ndf['TRADER']='ADRIANO TENENTE'
    ndf['Dealt to settlement exchange rate'] = np.where(ndf['Dealt to settlement exchange rate']==1, 0, 
                                                        ndf['Dealt to settlement exchange rate'])


    ndf['FX CURRENCY'] = np.where(ndf['Settlement currency ID']==ndf['Dealt currency'], 0, 
                                 ndf['Settlement currency ID'].astype(str)+'\\'+ndf['Dealt currency'].astype(str))


    ndf = ndf[['trade_date', 'settlement_date', 'Fund ID', 'Isin code', 'CUSIP', 'SEDOL', 'Symbol', ndf.columns[9], 'TRADE TYPE',
        'STRIKE PRICE', 'EXPIRY DATE', 'Volume', 'AvgPrc', 'Dealt currency', 'Settlement consideration', 'Settlement currency ID',
         'COUNTERPARTY', 'TRADER', 'Comm rate', 'Market charges total', 'Dealt to settlement exchange rate', 'FX CURRENCY']]

    ndf.columns = ['TRADE DATE','SETTLE DATE','FUND','ISIN','CUSIP','SEDOL','TICKER','BUY/SELL','TRADE TYPE','STRIKE PRICE',
                   'EXPIRY DATE','QUANTITY','PRICE','PRICE CURRENCY','NET AMOUNT','NET CURRENCY','COUNTERPARTY','TRADER','COMM',
                   'SEC FEES','FX RATE','FX CURRENCY']
    
    #print ('DataFrame da confirmação gerado')
    ndf
    
    return ndf, td

def get_any(df, coluna_procura, string_procura,input_colunas, output_colunas):
    #print ('Gerando confirmação do cliente: %s') % string_procura
    ndf = df[df[coluna_procura]==string_procura].reset_index(drop=True).copy()

    ndf['trade_date'] = pd.to_datetime(ndf['Trade Date'].str.split().str[0], format='%Y%m%d')
    ndf['settlement_date'] = pd.to_datetime(ndf['Value date'], format='%Y%m%d')
    td = pd.to_datetime(ndf['Trade Date'].str.split().str[0].drop_duplicates().reset_index(drop=True)[0], 
                       format='%Y%m%d')
    td = str(td.month)+'-'+str(td.day)

    ndf = ndf[input_colunas]
    
    try:
        ndf['Dealt to settlement exchange rate'] = np.where(ndf['Dealt to settlement exchange rate']==1,0,
                                                            ndf['Dealt to settlement exchange rate'])
    except:
        print('No exchange rates')
        
    ndf.columns = [output_colunas]
    
    #print ('DataFrame da confirmação gerado')
    return ndf, td


def get_kinea(df):

    ndf, td = get_any(df, 'Client/Book', 'KINEA',['Unnamed: 9', 'Fund ID', 'Symbol', 'Trade Date', 'Value date', 'Dealt currency', 
                                       'Volume', 'AvgPrc', 'Gross consideration', 'Comm rate', 'Market charges total',
                                       'Settlement consideration'], ['Position Type','Account Id','Security Identifier',
                                                                     'Trade Date','Settlement Date','Settlement CCY',
                                                                     'Quantity','PriceAmount','Principal','Commission Amount',
                                                                     'Tax or fees','Net Amount'])
    ndf['Transaction Type']='TR001'
    ndf['Transaction Status']='NEW' 
    ndf['Transaction Level']='A'
    ndf['Broker/Counterparty']='PACT'
    ndf['Price Indicator']='G'
    ndf['Commission Indicator']='F'
    ndf['Comments']='CASH'
    ndf['Asset Type']='STOCK'
    ndf = pd.concat([ndf, pd.DataFrame(columns=lista_blanks)], axis=1).fillna('')[['Transaction Type','Transaction Status','Buy Sell Indicator','Long Short Indicator','Position Type',
         'Transaction Level','Client Trade Ref No.','Associated Trade Id','Execution Account','Account Id',
         'Broker/Counterparty','Security Identifier Type','Security Identifier','Security Description','Trade Date',
         'Settlement Date','Settlement CCY','Exchange Code','Quantity','PriceAmount','Price Indicator','Principal',
         'Commission Amount','Commission Indicator','Tax or fees','Tax 2','Tax or fees indicator','Interest',
         'Interest indicator','Net Amount','Hearsay Ind','Custodian','Money Manager','Book id','Deal Id','TaxLot Id',
         'Original taxlot transaction date','Original Taxlot transaction price','TaxLot Closeout Method','Exchange Rate',
         'Acquisition Date','Comments','Asset Type','Trader ID']]
    ndf['Account Id'] = ndf['Account Id'].map(dict_contas)
    
    return ndf, td

    
lista_blanks = ['Buy Sell Indicator','Long Short Indicator','Client Trade Ref No.','Associated Trade Id','Execution Account',
    'Security Identifier Type','Security Description','Exchange Code','Tax 2','Tax or fees indicator','Interest',
    'Interest indicator','Hearsay Ind','Custodian','Money Manager','Book id','Deal Id','TaxLot Id',
    'Original taxlot transaction date','Original Taxlot transaction price','TaxLot Closeout Method','Exchange Rate',
    'Acquisition Date','Trader ID']

dict_contas = {
    'KGC':'038CDNSR7',
    'KGD':'038CDLWA3',
    'KGE':'038CDNSQ9',
    'KGF':'038CDNSS5'
}

# %%
def get_claritas(df):
    ndf = df[df['Client/Book'].str.contains("CLARITAS")].reset_index(drop=True).copy()

    ndf['trade_date'] = pd.to_datetime(ndf['Trade Date'].str.split().str[0], format='%Y%m%d')
    ndf['settlement_date'] = pd.to_datetime(ndf['Value date'], format='%Y%m%d')
    td = pd.to_datetime(ndf['Trade Date'].str.split().str[0].drop_duplicates().reset_index(drop=True)[0], 
                       format='%Y%m%d')
    data = str(td.year)+str(td.month)+str(td.day)
    td = str(td.month)+'-'+str(td.day)
    


    ndf['Gross Amount'] = ndf['Volume']*ndf['AvgPrc']

    ndf = ndf[['Fund ID', 'trade_date', 'settlement_date', 'Unnamed: 9', 'Symbol', 'Isin code', 'Volume', 'AvgPrc', 'Comm rate',
        'Market charges total', 'Dealt to settlement exchange rate', 'Gross Amount', 'Settlement consideration', 
        'Settlement currency ID']]

    ndf.columns=['Name of Fund','Execution Date','Settlement Date','Side','Ticker ','ISIN Number','Quantity','Avg Price',
                 'Commission','SEC Fee','FX RATE','Gross Amount','NetAmount','Sett CCY']

    ndf
    
    return ndf, td, data

# %% [markdown]
# # Confirmações prontas!

# %% [markdown]
# ### Se aparecer algo em um quadro vermelho, não quer dizer que deu erro!! funcinou, só que o código está depricated

# %% [markdown]
# ### GAP

# %%
ndf, td = get_gap(df)

# %%
ndf

# %%
out_path, cliente, td = salva_excel('GAP', df, td)

# %%
## CONFERE SE O EXCEL ESTÁ OK!!
email.email_sender(email_saida, 'Risco@gapasset.com.br;diogo@gapasset.com.br;raphael@gapasset.com.br;OL-EQUITYBD@btgpactual.com', 
            'Confirmação de movimentações %s TD %s' %(cliente, td),
             'Em anexo estão as movimentações do dia %s' % td, 
             [out_path])

# %% [markdown]
# ## SPX

# %%
ndf, td = get_spx(df)

# %%
out_path, cliente, td = salva_excel('SPX', df, td)

# %%
ndf
# Out:
#          T/D        S/D Side  Ticker          ISIN  Shares    Price  \
# 0 2018-06-05 2018-06-07  BUY  CCU.US  US2044291043   15000  25.5494
#
#    Principal  Commission  SEC Fee  Net Amount Settlement Account
# 0   383241.0       150.0      0.0   -383391.0             SPX_MS

# %%
## CONFERE SE O EXCEL ESTÁ OK!!
email.email_sender(email_saida, 'felipe.carvalho@spxcapital.com.br;controle@spxcapital.com.br;OL-EQUITYBD@btgpactual.com', 
            'Confirmação de movimentações %s TD %s' %(cliente, td),
             'Em anexo estão as movimentações do dia %s' % td, 
             [out_path])

# %% [markdown]
# ## Asset

# %%
ndf, td = get_asset(df, 'ASSETBTG')

# %%
ndf = ndf.sort_values(by=['TICKER', 'FUND'])

# %%
out_path, cliente, td = salva_excel('ASSETBTG', df, td)

# %%
ndf
# Out:
#    TRADE DATE SETTLE DATE      FUND          ISIN CUSIP SEDOL   TICKER  \
# 9  2018-06-05  2018-06-07       ARF  BMG2519Y1084               BAP.US
# 10 2018-06-05  2018-06-07    CAYMAN  BMG2519Y1084               BAP.US
# 8  2018-06-05  2018-06-07      GEMM  BMG2519Y1084               BAP.US
# 14 2018-06-05  2018-06-07  OP_LATIN  BMG2519Y1084               BAP.US
# 13 2018-06-05  2018-06-07  SICAV_LA  BMG2519Y1084               BAP.US
# 7  2018-06-05  2018-06-07    CAYMAN  US03524A1088               BUD.US
# 0  2018-06-05  2018-06-07    NORGES  US03524A1088               BUD.US
# 6  2018-06-05  2018-06-07  OP_LATIN  US03524A1088               BUD.US
# 4  2018-06-05  2018-06-07       ARF  US05968L1026               CIB.US
# 5  2018-06-05  2018-06-07    CAYMAN  US05968L1026               CIB.US
# 3  2018-06-05  2018-06-07      GEMM  US05968L1026               CIB.US
# 2  2018-06-05  2018-06-07    CAYMAN  US58733R1023              MELI.US
# 1  2018-06-05  2018-06-07    NORGES  US58733R1023              MELI.US
# 12 2018-06-05  2018-06-07  OP_LATIN  US84265V1052              SCCO.US
# 11 2018-06-05  2018-06-07  SICAV_LA  US84265V1052              SCCO.US
#
#    BUY/SELL TRADE TYPE STRIKE PRICE     ...          PRICE  PRICE CURRENCY  \
# 9         S     EQUITY                  ...       227.9182             USD
# 10        S     EQUITY                  ...       227.9182             USD
# 8         S     EQUITY                  ...       227.9182             USD
# 14        S     EQUITY                  ...       227.9091             USD
# 13        S     EQUITY                  ...       227.9091             USD
# 7         S     EQUITY                  ...        95.1800             USD
# 0         B     EQUITY                  ...        95.2225             USD
# 6         B     EQUITY                  ...        95.3000             USD
# 4         B     EQUITY                  ...        47.8968             USD
# 5         B     EQUITY                  ...        47.8968             USD
# 3         B     EQUITY                  ...        47.8968             USD
# 2         S     EQUITY                  ...       311.3700             USD
# 1         B     EQUITY                  ...       309.0980             USD
# 12        B     EQUITY                  ...        50.9692             USD
# 11        B     EQUITY                  ...        50.9692             USD
#
#     NET AMOUNT NET CURRENCY                COUNTERPARTY           TRADER  \
# 9     92985.34          USD  BTG PACTUAL US CAPITAL LLC  ADRIANO TENENTE
# 10   343225.28          USD  BTG PACTUAL US CAPITAL LLC  ADRIANO TENENTE
# 8     64725.09          USD  BTG PACTUAL US CAPITAL LLC  ADRIANO TENENTE
# 14   413631.49          USD  BTG PACTUAL US CAPITAL LLC  ADRIANO TENENTE
# 13    18231.69          USD  BTG PACTUAL US CAPITAL LLC  ADRIANO TENENTE
# 7      9516.87          USD  BTG PACTUAL US CAPITAL LLC  ADRIANO TENENTE
# 0   4952090.00          USD  BTG PACTUAL US CAPITAL LLC  ADRIANO TENENTE
# 6    142965.00          USD  BTG PACTUAL US CAPITAL LLC  ADRIANO TENENTE
# 4     92939.19          USD  BTG PACTUAL US CAPITAL LLC  ADRIANO TENENTE
# 5    342868.97          USD  BTG PACTUAL US CAPITAL LLC  ADRIANO TENENTE
# 3     64722.09          USD  BTG PACTUAL US CAPITAL LLC  ADRIANO TENENTE
# 2     15567.79          USD  BTG PACTUAL US CAPITAL LLC  ADRIANO TENENTE
# 1   6182160.00          USD  BTG PACTUAL US CAPITAL LLC  ADRIANO TENENTE
# 12   430519.34          USD  BTG PACTUAL US CAPITAL LLC  ADRIANO TENENTE
# 11    20136.78          USD  BTG PACTUAL US CAPITAL LLC  ADRIANO TENENTE
#
#       COMM SEC FEES  FX RATE  FX CURRENCY
# 9     4.08     1.21      0.0            0
# 10   15.06     4.47      0.0            0
# 8     2.84     0.84      0.0            0
# 14   18.15     5.38      0.0            0
# 13    0.80     0.24      0.0            0
# 7     1.00     0.13      0.0            0
# 0   520.00     0.00      0.0            0
# 6    15.00     0.00      0.0            0
# 4    19.40     0.00      0.0            0
# 5    71.57     0.00      0.0            0
# 3    13.51     0.00      0.0            0
# 2     0.50     0.21      0.0            0
# 1   200.00     0.00      0.0            0
# 12   84.45     0.00      0.0            0
# 11    3.95     0.00      0.0            0
#
# [15 rows x 22 columns]

# %%
## CONFERE SE O EXCEL ESTÁ OK!!
email.email_sender(email_saida, 'OL-equity-backoffice@btgpactual.com;OL-BTG-Ops-Brazil@btgpactual.com;OL-hedgefundsadm@btgpactual.com;ol-fundadm-trades@btgpactual.com;OL-EQUITYBD@btgpactual.com', 
            'Confirmação de movimentações %s TD %s' %(cliente, td),
             'Em anexo estão as movimentações do dia %s' % td, 
             [out_path])

# %% [markdown]
# ## Sura

# %%
ndf, td = get_asset(df, 'SURA_')

# %%
ndf

# %%
out_path, cliente, td = salva_excel('SURA', df, td)

# %%
## CONFERE SE O EXCEL ESTÁ OK!!
email.email_sender(email_saida, 'Paulina.Zuniga@sura.cl;Fabian.Gonzalez@Sura.cl;Marco.Gomez@Sura.cl;CustodiaAGF@sura.cl;OL-EQUITYBD@btgpactual.com', 
            'Confirmação de movimentações %s TD %s' %(cliente, td),
             'Em anexo estão as movimentações do dia %s' % td, 
             [out_path])

# %% [markdown]
# ## Kinea

# %%
ndf, td = get_kinea(df)

# %%
ndf

# %%
out_path, cliente, td = salva_excel('KINEA', df, td)

# %%
email.email_sender(email_saida, 'middleKinea@kinea.com.br;guilherme.colombini@kinea.com.br;ricardo-yukio.sakai@kinea.com.br;OL-EQUITYBD@btgpactual.com', 
            'Confirmação de movimentações %s TD %s' %(cliente, td),
             'Em anexo estão as movimentações do dia %s' % td, 
             [out_path])

# %% [markdown]
# ## Locais

# %% [markdown]
# ### Mexico

# %%
ndf, td = get_any(df, 'Exchange ID', 'MEX', ['Exchange ID', 'trade_date', 'settlement_date', 'Broker of Interest code', 'Client/Book', 'Fund ID', 'Symbol',
        'Isin code', 'Unnamed: 9', 'Volume', 'AvgPrc', 'Gross consideration', 'Comm rate', 'Comm type', 
         'Dealt to settlement exchange rate', 'Settlement consideration', 'Settlement currency ID'],
       ['Market','TD','SD','Client Account','Client Group','Client Allocation','Security','ISIN','Buy/Sell','Amount',
        'Price','Principal','Comm','Comm Type','FX Rate','Net amount ','Settle CCY'])

# %%
ndf['Matched']='No'
ndf['Settled']='No'
ndf = ndf.sort_values(by='Client Group')
out_path, cliente, td = salva_excel('RecapMex', df, td)

# %%
ndf
# Out:
#    Market         TD         SD Client Account Client Group Client Allocation  \
# 53    MEX 2018-06-05 2018-06-07      0426263-9    BESTINVER             LATAM
# 2     MEX 2018-06-05 2018-06-07      0426263-9    BESTINVER             LATAM
# 51    MEX 2018-06-05 2018-06-07      0426263-9    BESTINVER             LATAM
# 26    MEX 2018-06-05 2018-06-07      0332812-9      COMGEST         CG_GEM_PC
# 5     MEX 2018-06-05 2018-06-07     LBG0376770        DAIWA              9306
# 3     MEX 2018-06-05 2018-06-07     LBG0224550          DRZ          SRH12EMG
# 4     MEX 2018-06-05 2018-06-07     LBG0338250          DRZ          EMFUNDLP
# 52    MEX 2018-06-05 2018-06-07     LBG0450500         FNY_             FNY__
# 47    MEX 2018-06-05 2018-06-07     LBG0270740        ITAU_        MILLATAMEQ
# 50    MEX 2018-06-05 2018-06-07     LBG0270090        ITAU_          BPILATAM
# 49    MEX 2018-06-05 2018-06-07     LBG0270580        ITAU_       GLORYLATAMF
# 31    MEX 2018-06-05 2018-06-07     LBG0270090        ITAU_          BPILATAM
# 32    MEX 2018-06-05 2018-06-07     LBG0270580        ITAU_       GLORYLATAMF
# 33    MEX 2018-06-05 2018-06-07     LBG0332130        ITAU_          KIALATAM
# 34    MEX 2018-06-05 2018-06-07     LBG0270740        ITAU_        MILLATAMEQ
# 35    MEX 2018-06-05 2018-06-07     LBG0270090        ITAU_          BPILATAM
# 48    MEX 2018-06-05 2018-06-07     LBG0332130        ITAU_          KIALATAM
# 37    MEX 2018-06-05 2018-06-07     LBG0270580        ITAU_       GLORYLATAMF
# 38    MEX 2018-06-05 2018-06-07     LBG0270250        ITAU_       NORDEALATAM
# 40    MEX 2018-06-05 2018-06-07     LBG0270740        ITAU_        MILLATAMEQ
# 41    MEX 2018-06-05 2018-06-07     LBG0270090        ITAU_          BPILATAM
# 42    MEX 2018-06-05 2018-06-07     LBG0270580        ITAU_       GLORYLATAMF
# 43    MEX 2018-06-05 2018-06-07     LBG0332130        ITAU_          KIALATAM
# 44    MEX 2018-06-05 2018-06-07     LBG0270740        ITAU_        MILLATAMEQ
# 45    MEX 2018-06-05 2018-06-07     LBG0270250        ITAU_       NORDEALATAM
# 46    MEX 2018-06-05 2018-06-07     LBG0270250        ITAU_       NORDEALATAM
# 36    MEX 2018-06-05 2018-06-07     LBG0270250        ITAU_       NORDEALATAM
# 39    MEX 2018-06-05 2018-06-07     LBG0332130        ITAU_          KIALATAM
# 24    MEX 2018-06-05 2018-06-07      0343193-0    NEUBERGER          77706839
# 23    MEX 2018-06-05 2018-06-07     LBG0469910    NEUBERGER          77706713
# 6     MEX 2018-06-05 2018-06-07     LBG0372480    NEUBERGER          55520676
# 7     MEX 2018-06-05 2018-06-07     LBG0372550    NEUBERGER          77700110
# 8     MEX 2018-06-05 2018-06-07     LBG0372630    NEUBERGER          77700111
# 9     MEX 2018-06-05 2018-06-07     LBG0372710    NEUBERGER          77700112
# 10    MEX 2018-06-05 2018-06-07     LBG0372890    NEUBERGER          77700905
# 11    MEX 2018-06-05 2018-06-07     LBG0373050    NEUBERGER          77701377
# 12    MEX 2018-06-05 2018-06-07     LBG0373130    NEUBERGER          77701757
# 13    MEX 2018-06-05 2018-06-07     LBG0373210    NEUBERGER          77701758
# 14    MEX 2018-06-05 2018-06-07     LBG0373390    NEUBERGER          77701759
# 15    MEX 2018-06-05 2018-06-07     LBG0373470    NEUBERGER          77701799
# 16    MEX 2018-06-05 2018-06-07     LBG0373540    NEUBERGER          77701887
# 17    MEX 2018-06-05 2018-06-07     LBG0373620    NEUBERGER          77701897
# 18    MEX 2018-06-05 2018-06-07     LBG0373700    NEUBERGER          77702847
# 19    MEX 2018-06-05 2018-06-07     LBG0373880    NEUBERGER          77704787
# 20    MEX 2018-06-05 2018-06-07     LBG0373960    NEUBERGER          77704893
# 21    MEX 2018-06-05 2018-06-07     LBG0374040    NEUBERGER          77705235
# 22    MEX 2018-06-05 2018-06-07     LBG0372220    NEUBERGER          77705407
# 25    MEX 2018-06-05 2018-06-07     LBG0372300    NEUBERGER          77707012
# 0     MEX 2018-06-05 2018-06-07     LBG0427840   PACIFIC_AM            PAAMCO
# 27    MEX 2018-06-05 2018-06-07     LBG0427840   PACIFIC_AM            PAAMCO
# 29    MEX 2018-06-05 2018-06-07     LBG0427840   PACIFIC_AM            PAAMCO
# 28    MEX 2018-06-05 2018-06-07     LBG0427840   PACIFIC_AM            PAAMCO
# 1     MEX 2018-06-05 2018-06-07     LBG0427840   PACIFIC_AM            PAAMCO
# 30    MEX 2018-06-05 2018-06-07     LBG0427840   PACIFIC_AM            PAAMCO
# 54    MEX 2018-06-05 2018-06-07     LBG0427840   PACIFIC_AM            PAAMCO
#
#          Security          ISIN Buy/Sell  Amount     Price    Principal  \
# 53      GRUMAB.MX  MXP4948K1056        B   27840  220.2055   6130521.12
# 2       BOLSAA.MX  MX01BM1B0000        B   41112   32.4453   1333891.17
# 51    FEMSAUBD.MX  MXP320321310        B   36900  165.7571   6116436.99
# 26      HCITY*.MX  MX01HC000001        S  533500   24.1891  12904884.85
# 5         GCC*.MX  MX01GC2M0006        S    2500  109.9320    274830.00
# 3         GAPB.MX  MX01GA000004        S    9500  168.8301   1603885.95
# 4         GAPB.MX  MX01GA000004        S   56570  168.8301   9550718.76
# 52    GMEXICOB.MX  MXP370841019        S   35000   57.3053   2005685.50
# 47     TERRA13.MX  MXCFTE0B0005        S    9500   28.4359    270141.05
# 50     TERRA13.MX  MXCFTE0B0005        S   16600   28.4359    472035.94
# 49     TERRA13.MX  MXCFTE0B0005        S  139200   28.4359   3958277.28
# 31   FIBRAPL14.MX  MXCFFI170008        B     547   35.9269     19652.01
# 32   FIBRAPL14.MX  MXCFFI170008        B    4597   35.9269    165155.96
# 33   FIBRAPL14.MX  MXCFFI170008        B    1807   35.9269     64919.91
# 34   FIBRAPL14.MX  MXCFFI170008        B     314   35.9269     11281.05
# 35   FIBRAPL14.MX  MXCFFI170008        B    3785   35.6049    134764.55
# 48     TERRA13.MX  MXCFTE0B0005        S   54700   28.4359   1555443.73
# 37   FIBRAPL14.MX  MXCFFI170008        B   31828   35.6049   1133232.76
# 38   FIBRAPL14.MX  MXCFFI170008        B    9936   35.6049    353770.29
# 40   FIBRAPL14.MX  MXCFFI170008        B    2177   35.6049     77511.87
# 41   FIBRAPL14.MX  MXCFFI170008        B    1991   35.7738     71225.64
# 42   FIBRAPL14.MX  MXCFFI170008        B   16744   35.7738    598996.51
# 43   FIBRAPL14.MX  MXCFFI170008        B    6581   35.7738    235427.38
# 44   FIBRAPL14.MX  MXCFFI170008        B    1145   35.7738     40961.00
# 45   FIBRAPL14.MX  MXCFFI170008        B    5227   35.7738    186989.65
# 46     TERRA13.MX  MXCFTE0B0005        S   43400   28.4359   1234118.06
# 36   FIBRAPL14.MX  MXCFFI170008        B    1435   35.9267     51554.81
# 39   FIBRAPL14.MX  MXCFFI170008        B   12509   35.6049    445381.69
# 24      GICSAB.MX  MX01GI020004        S   24367    9.0005    219315.18
# 23      GICSAB.MX  MX01GI020004        S    5789    9.0005     52103.89
# 6       GICSAB.MX  MX01GI020004        S   73212    9.0005    658944.61
# 7       GICSAB.MX  MX01GI020004        S    3020    9.0005     27181.51
# 8       GICSAB.MX  MX01GI020004        S   12309    9.0005    110787.15
# 9       GICSAB.MX  MX01GI020004        S   27635    9.0005    248728.82
# 10      GICSAB.MX  MX01GI020004        S   29144    9.0005    262310.57
# 11      GICSAB.MX  MX01GI020004        S   14768    9.0005    132919.38
# 12      GICSAB.MX  MX01GI020004        S   45073    9.0005    405679.54
# 13      GICSAB.MX  MX01GI020004        S   11358    9.0005    102227.68
# 14      GICSAB.MX  MX01GI020004        S   56730    9.0005    510598.37
# 15      GICSAB.MX  MX01GI020004        S   28552    9.0005    256982.28
# 16      GICSAB.MX  MX01GI020004        S    5121    9.0005     46091.56
# 17      GICSAB.MX  MX01GI020004        S   24952    9.0005    224580.48
# 18      GICSAB.MX  MX01GI020004        S   15854    9.0005    142693.93
# 19      GICSAB.MX  MX01GI020004        S   16327    9.0005    146951.16
# 20      GICSAB.MX  MX01GI020004        S   57772    9.0005    519976.89
# 21      GICSAB.MX  MX01GI020004        S   24330    9.0005    218982.17
# 22      GICSAB.MX  MX01GI020004        S    6397    9.0005     57576.20
# 25      GICSAB.MX  MX01GI020004        S   13725    9.0005    123531.86
# 0          AC*.MX  MX01AC100006        B  100000  116.9162  11691620.00
# 27     IENOVA*.MX  MX01IE060002        B   15000   79.0000   1185000.00
# 29          RA.MX  MX01R0000006        S   10440  110.0000   1148400.00
# 28  LACOMERUBC.MX  MX01LA050010        B   76370   18.5868   1419473.92
# 1     BACHOCOB.MX  MX01BA1D0003        S     500   91.0000     45500.00
# 30     BBAJIOO.MX  MX41BB000000        B  127049   38.5353   4895871.33
# 54      BIMBOA.MX  MXP495211262        B    8920   36.7000    327364.00
#
#             Comm Comm Type  FX Rate  Net amount  Settle CCY Matched Settled
# 53   6130.521120        BP      0.0   6136651.64        MXN      No      No
# 2    1333.891170        BP      0.0   1335225.06        MXN      No      No
# 51   6116.436990        BP      0.0   6122553.43        MXN      No      No
# 26  11614.390000        BP      0.0  12893270.46        MXN      No      No
# 5     549.660000        BP      0.0    274280.34        MXN      No      No
# 3    3207.771984        BP      0.0   1600678.18        MXN      No      No
# 4   19101.438020        BP      0.0   9531617.32        MXN      No      No
# 52   3008.530000        BP      0.0   2002676.97        MXN      No      No
# 47    405.211704        BP      0.0    269735.84        MXN      No      No
# 50    708.054136        BP      0.0    471327.89        MXN      No      No
# 49   5937.417818        BP      0.0   3952339.86        MXN      No      No
# 31     29.477766        BP      0.0     19681.49        MXN      No      No
# 32    247.731792        BP      0.0    165403.69        MXN      No      No
# 33     97.379019        BP      0.0     65017.29        MXN      No      No
# 34     16.921423        BP      0.0     11297.97        MXN      No      No
# 35    202.147098        BP      0.0    134966.69        MXN      No      No
# 48   2333.166341        BP      0.0   1553110.56        MXN      No      No
# 37   1699.851479        BP      0.0   1134932.61        MXN      No      No
# 38    353.770000        BP      0.0    354124.06        MXN      No      No
# 40    116.267961        BP      0.0     77628.14        MXN      No      No
# 41    106.838771        BP      0.0     71332.47        MXN      No      No
# 42    898.497429        BP      0.0    599895.00        MXN      No      No
# 43    353.142116        BP      0.0    235780.52        MXN      No      No
# 44     61.441684        BP      0.0     41022.44        MXN      No      No
# 45    186.990000        BP      0.0    187176.64        MXN      No      No
# 46   1234.120000        BP      0.0   1232883.94        MXN      No      No
# 36     51.550000        BP      0.0     51606.36        MXN      No      No
# 39    668.073462        BP      0.0    446049.77        MXN      No      No
# 24    438.630542        BP      0.0    218876.55        MXN      No      No
# 23    104.207831        BP      0.0     51999.69        MXN      No      No
# 6    1317.889738        BP      0.0    657626.72        MXN      No      No
# 7      54.363042        BP      0.0     27127.15        MXN      No      No
# 8     221.574397        BP      0.0    110565.58        MXN      No      No
# 9     497.457833        BP      0.0    248231.36        MXN      No      No
# 10    524.621353        BP      0.0    261785.95        MXN      No      No
# 11    265.838874        BP      0.0    132653.55        MXN      No      No
# 12    811.359397        BP      0.0    404868.18        MXN      No      No
# 13    204.455440        BP      0.0    102023.22        MXN      No      No
# 14   1021.197137        BP      0.0    509577.17        MXN      No      No
# 15    513.964757        BP      0.0    256468.31        MXN      No      No
# 16     92.183158        BP      0.0     45999.38        MXN      No      No
# 17    449.161131        BP      0.0    224131.31        MXN      No      No
# 18    285.387968        BP      0.0    142408.54        MXN      No      No
# 19    293.902444        BP      0.0    146657.26        MXN      No      No
# 20   1039.954187        BP      0.0    518936.93        MXN      No      No
# 21    437.964505        BP      0.0    218544.20        MXN      No      No
# 22    115.152443        BP      0.0     57461.05        MXN      No      No
# 25    247.063824        BP      0.0    123284.80        MXN      No      No
# 0    8184.130000        BP      0.0  11699804.13        MXN      No      No
# 27    829.500000        BP      0.0   1185829.50        MXN      No      No
# 29    803.880000        BP      0.0   1147596.12        MXN      No      No
# 28    993.630000        BP      0.0   1420467.55        MXN      No      No
# 1      31.850000        BP      0.0     45468.15        MXN      No      No
# 30   3427.110000        BP      0.0   4899298.44        MXN      No      No
# 54    229.150000        BP      0.0    327593.15        MXN      No      No

# %%
email.email_sender(email_saida, 'Elena.Gomez@btgpactual.com;Francisco.Acosta@btgpactual.com;Luis.Paz@btgpactual.com;OL-EQUITYBD@btgpactual.com', 
            'Confirmação de movimentações %s TD %s' %(cliente, td),
             'Em anexo estão as movimentações do dia %s' % td, 
             [out_path])

# %% [markdown]
# ### Celfin

# %% [markdown]
# #### Peru

# %%
ndf, td = get_any(df, 'Exchange ID', 'LMA', ['Exchange ID', 'trade_date', 'settlement_date', 'Client/Book', 'Fund ID', 'Symbol',
        'Unnamed: 9', 'AvgPrc', 'Volume',  'Comm rate.1'],['Exchange', 'Trade Date', 'Settlement Date', 'Client/Book',
                                                       'Fund ID', 'Symbol', 'Side','Average Price', 'Quantity',
                                                        'Commission rate'])
ndf = ndf.sort_values(by='Client/Book')
# Out:
# No exchange rates

# %%
ndf
# Out:
#   Exchange Trade Date Settlement Date Client/Book        Fund ID       Symbol  \
# 0      LMA 2018-06-11      2018-06-13         HDI  BLACKWELL_LLC       IFS.LM
# 1      LMA 2018-06-11      2018-06-13         HDI   HUMAN_DEV_LP       IFS.LM
# 2      LMA 2018-06-11      2018-06-13       TROWE           9086  ALICORC1.LM
# 3      LMA 2018-06-11      2018-06-13       TROWE           9375   INRETC1.LM
# 4      LMA 2018-06-11      2018-06-13       TROWE           9304  ALICORC1.LM
#
#   Side  Average Price  Quantity  Commission rate
# 0    S          41.00     74430             21.3
# 1    S          41.00     15766             21.3
# 2    S          11.80     77540             15.0
# 3    S          25.99      2367             15.0
# 4    S          11.80      1792             15.0

# %%
out_path, cliente, td = salva_excel('CelfinPeru', df, td)

# %%
email.email_sender(email_saida, 'henry.rivera@btgpactual.com;OL-EQUITYBD@btgpactual.com;OL-Equipo.Operaciones.Peru@btgpactual.com', 
            'Confirmação de movimentações %s TD %s' %(cliente, td),
             'Em anexo estão as movimentações do dia %s' % td, 
             [out_path])

# %% [markdown]
# #### Colombia

# %%
ndf, td = get_any(df, 'Exchange ID', 'COL', ['Exchange ID', 'trade_date', 'settlement_date', 'Client/Book', 'Fund ID', 'Symbol',
        'Unnamed: 9', 'AvgPrc', 'Volume',  'Comm rate.1'],['Exchange', 'Trade Date', 'Settlement Date', 'Client/Book',
                                                       'Fund ID', 'Symbol', 'Side','Average Price', 'Quantity',
                                                        'Commission rate'])
ndf = ndf.sort_values(by='Client/Book')
# Out:
# No exchange rates

# %%
ndf
# Out:
#   Exchange Trade Date Settlement Date   Client/Book  Fund ID        Symbol  \
# 0      COL 2018-06-05      2018-06-08      HSBC_GAM  UKUS803  PFDAVVNDA.BG
# 1      COL 2018-06-05      2018-06-08      HSBC_GAM  UKLX563  PFDAVVNDA.BG
# 2      COL 2018-06-05      2018-06-08      HSBC_GAM  UKUS802  PFDAVVNDA.BG
# 3      COL 2018-06-05      2018-06-08  TEMPLETON_US    12772  PFDAVVNDA.BG
# 4      COL 2018-06-05      2018-06-08  TEMPLETON_US    12904  PFDAVVNDA.BG
#
#   Side  Average Price  Quantity  Commission rate
# 0    S     34662.6183      1396             15.0
# 1    S     34662.6183     26501             15.0
# 2    S     34662.6183      8493             15.0
# 3    B     34680.0000       500             25.0
# 4    B     34680.0000      6599             25.0

# %%
out_path, cliente, td = salva_excel('CelfinColombia', df, td)

# %%
email.email_sender(email_saida, 'OL-OPSColombia-BD@btgpactual.com;SH-LatamBD@btgpactual.com;Nicolas.Velasquez@btgpactual.com;OL-EQUITYBD@btgpactual.com', 
            'Confirmação de movimentações %s TD %s' %(cliente, td),
             'Em anexo estão as movimentações do dia %s' % td, 
             [out_path])

# %% [markdown]
# #### Chile

# %%
ndf, td = get_any(df, 'Exchange ID', 'SGO', ['Exchange ID', 'trade_date', 'settlement_date', 'Client/Book', 'Fund ID', 'Symbol',
        'Unnamed: 9', 'AvgPrc', 'Volume',  'Comm rate.1'],['Exchange', 'Trade Date', 'Settlement Date', 'Client/Book',
                                                       'Fund ID', 'Symbol', 'Side','Average Price', 'Quantity',
                                                        'Commission rate'])

# %%
out_path, cliente, td = salva_excel('CelfinChile', df, td)

# %%
ndf

# %%
email.email_sender(email_saida, 'guilherme.correia@btgpactual.com', 
            'Confirmação de movimentações %s TD %s' %(cliente, td),
             'Em anexo estão as movimentações do dia %s' % td, 
             [out_path])

# %% [markdown]
# ## Claritas

# %%
ndf, td, data = get_claritas(df)

# %%
data = ndf['Execution Date'].drop_duplicates().reset_index(drop=True)[0]

# %%
ano = "{:02}".format(data.year)
mes = "{:02}".format(data.month)
dia = data.day

ref_pasta = str(ano)+str(mes)+str(dia)
data = str(dia)+'/'+str(mes)+'/'+str(ano)

j = ndf.shape[0]

# %%
out_path, cliente, td = salva_excel('CLARITAS', df, td)

# %%
email.email_confirmation('Claritas', 'CLARITAS', data, email_saida, 'confirmations', 'Caixa de Entrada', j)

# %%
pasta = r'C:\Users\correigu\OneDrive - Banco BTG Pactual S.A\Documents\offshore\Claritas'+'\\'+ref_pasta

# %%
lista_files = [out_path]
for file in os.listdir(pasta):
    lista_files.append(pasta+'\\'+file)
    
print ('Serão anexados %s arquivos ao e-mail') % len(lista_files)

# %%
email.email_sender(email_saida, 'guilherme.correia@btgpactual.com', 
            'Confirmação de movimentações %s TD %s' %(cliente, td),
             'Em anexo estão as movimentações do dia %s' % td, 
            lista_files)
