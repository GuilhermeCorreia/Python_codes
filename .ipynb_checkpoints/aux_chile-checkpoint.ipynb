# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
sys.path.append('%s/../' % os.getcwd())

import datetime
import pandas as pd
import numpy as np
import getpass

# %%
pasta = r'C:\Users\correigu\OneDrive - Banco BTG Pactual S.A\Desktop\aqruivos_offshore\janfev'

# %%
for file in os.listdir(pasta):
    data = file[-12:-4]
    ano = str(data[:4])
    mes = str(data[4:6])
    dia = str(data[-2:])
    
    name = 'Ajuste - Daily Stock Loan Fee Summary - %s-%s-%s.csv' %(ano, mes, dia)
    
    os.rename(pasta+'\\'+file, pasta+'\\'+name)

# %%
for file in os.listdir(pasta):
    df = pd.read_csv(pasta+'\\'+file, skipfooter=1)
    data = df['Value Date'].drop_duplicates()[0]
    year = data[-4:]
    day = data[-7:-5]
    month = data[:2]
    data_ref = year+month+day
    
    if '038CDB895' in file:
        string = '038CDB895_IN150DX - ' + data_ref
        os.rename(pasta+'\\'+file, pasta+'\\'+string+'.csv')
        
    elif '038CDBD08' in file:
        string = '038CDBD08_IN150DX - ' + data_ref
        os.rename(pasta+'\\'+file, pasta+'\\'+string+'.csv')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   app.launch_new_instance()

# %%
for file in os.listdir(pasta): 
    if 'Cayman - UBS' in file:
        data = file[-14:-4]
        try:
            ubs
        except:
            ubs = pd.read_excel(pasta+'\\'+file)
            ubs['conta']= 'ubs'
        else:
            ubs_1 = pd.read_excel(pasta+'\\'+file)
            ubs_1['conta']= 'ubs'
            ubs = pd.concat([ubs,ubs_1], axis=0)
        
    elif 'Cayman - MS' in file:
        try:
            morgan
        except:
            morgan = pd.read_excel(pasta+'\\'+file)
            morgan['conta'] = 'morgan'
        else:
            morgan_1 = pd.read_excel(pasta+'\\'+file)
            morgan_1['conta'] = 'morgan'
            morgan = pd.concat([morgan, morgan_1], axis = 0)

    
    elif 'Calypso - INT C' in file:
        try:
            intc
        except:
            intc = pd.read_excel(pasta+'\\'+file)
            intc['conta'] = 'intc'
        else:
            intc_1 = pd.read_excel(pasta+'\\'+file)
            intc_1['conta'] = 'intc'
            intc = pd.concat([intc, intc_1], axis = 0)

# %%
dash = pd.concat([ubs,morgan,intc],axis=0)

# %%
dash
# Out:
#     Account Name                Asset Description Currency  Daily Loan Cost  \
# 0            NaN                   Equity.AMZN US      USD         0.090000
# 1            NaN                   Equity.TSLA US      USD        -6.890000
# 2            NaN                   Equity.PAGS US      USD      -102.610000
# 3            NaN  ADR.ENIC US(Equity.ENELCHIL CI)      USD         0.000000
# 4            NaN                    Equity.ECH US      USD       -18.270000
# 5            NaN                    Equity.ECH US      USD       -32.200000
# 6            NaN                    Equity.EWZ US      USD        66.790000
# 7            NaN                    Equity.EWW US      USD       -63.860000
# 8            NaN                    Equity.EWW US      USD      -957.500000
# 9            NaN   ADR.BVN US(Equity.BUENAVC1 PE)      USD        13.620000
# 10           NaN     ADR.VCO US(Equity.CONCHA CI)      USD         0.000000
# 11           NaN                    Equity.HYG US      USD     -1246.330000
# 12           NaN                    Equity.TAL US      USD         0.110000
# 13           NaN    ADR.TV US(Equity.TLEVICPO MM)      USD        59.210000
# 14           NaN      ADR.BSAC US(Equity.BSAN CI)      USD         2.090000
# 15           NaN                    Equity.TGT US      USD        13.700000
# 16           NaN                    Equity.GME US      USD       -13.980000
# 17           NaN                    Equity.JCP US      USD       -60.010000
# 18           NaN                    Equity.EWW US      USD      -957.500000
# 19           NaN                    Equity.EWW US      USD       -63.860000
# 20           NaN                    Equity.EPU US      USD       -23.840000
# 21           NaN                    Equity.ECH US      USD       -18.270000
# 22           NaN                    Equity.ECH US      USD       -32.200000
# 23           NaN                    Equity.XLE US      USD        91.260000
# 24           NaN                    Equity.XLP US      USD       448.960000
# 25           NaN                    Equity.SPY US      USD       390.760000
# 26           NaN                   Equity.SONC US      USD       -20.800000
# 27           NaN                    Equity.DRI US      USD        18.330000
# 28           NaN     ADR.BSMX US(Equity.BSMXB MM)      USD        56.710000
# 29           NaN                    Equity.BKE US      USD      -120.900000
# ..           ...                              ...      ...              ...
# 3            NaN         ADR.TSU US(Equity.TIMP3)      USD         1.200000
# 4            NaN                   Equity.GAPB MM      MXN        60.290000
# 5            NaN        ADR.LTM US(Equity.LTM CI)      USD         5.500000
# 6            NaN         ADR.EBR US(Equity.ELET3)      USD       202.350000
# 7            NaN         ADR.SID US(Equity.CSNA3)      USD         0.100000
# 8            NaN        ADR.VALE US(Equity.VALE3)      USD       217.029465
# 9            NaN         ADR.PBR US(Equity.PETR3)      USD       163.881589
# 10           NaN        ADR.ITUB US(Equity.ITUB4)      USD         0.470000
# 11           NaN         ADR.ERJ US(Equity.EMBR3)      USD        20.320000
# 12           NaN                    Equity.FMG AU      AUD        85.240000
# 13           NaN         ADR.VIV US(Equity.VIVT4)      USD         0.620000
# 14           NaN         ADR.PBR US(Equity.PETR3)      USD         1.549138
# 15           NaN        ADR.VALE US(Equity.VALE3)      USD         2.770535
# 0            NaN        ADR.BRFS US(Equity.BRFS3)      USD         0.230000
# 1            NaN         ADR.PBR US(Equity.PETR3)      USD        46.131626
# 2            NaN       ADR.PBR/A US(Equity.PETR4)      USD         0.670000
# 3            NaN         ADR.TSU US(Equity.TIMP3)      USD         3.410000
# 4            NaN                   Equity.GAPB MM      MXN        59.610000
# 5            NaN        ADR.LTM US(Equity.LTM CI)      USD         7.860000
# 6            NaN       ADR.PAC US(Equity.GAPB MM)      USD         0.980000
# 7            NaN         ADR.EBR US(Equity.ELET3)      USD       278.590000
# 8            NaN         ADR.SID US(Equity.CSNA3)      USD         0.100000
# 9            NaN        ADR.VALE US(Equity.VALE3)      USD       216.019862
# 10           NaN         ADR.PBR US(Equity.PETR3)      USD       164.869356
# 11           NaN        ADR.ITUB US(Equity.ITUB4)      USD         0.460000
# 12           NaN         ADR.ERJ US(Equity.EMBR3)      USD         6.360000
# 13           NaN                    Equity.FMG AU      AUD        85.600000
# 14           NaN         ADR.VIV US(Equity.VIVT4)      USD         0.630000
# 15           NaN         ADR.PBR US(Equity.PETR3)      USD         1.559018
# 16           NaN        ADR.VALE US(Equity.VALE3)      USD         2.760138
#
#             Institution                      Operator Position Date    Sedol  \
# 0    UBS SECURITIES LLC                BD_CLIENTS_UBS    01/03/2018  2000019
# 1    UBS SECURITIES LLC           PRIVATE_DEFAULT_UBS    01/03/2018  B616C79
# 2    UBS SECURITIES LLC           PRIVATE_DEFAULT_UBS    01/03/2018  BFWK4R7
# 3    UBS SECURITIES LLC                BD_CLIENTS_UBS    01/03/2018  BYYHKR1
# 4    UBS SECURITIES LLC  SICAV LATAM HEDGE.CAYMAN_UBS    01/03/2018  B29FC81
# 5    UBS SECURITIES LLC  SICAV LATAM HEDGE.CAYMAN_UBS    01/03/2018  B29FC81
# 6    UBS SECURITIES LLC  SICAV LATAM HEDGE.CAYMAN_UBS    01/03/2018  2726014
# 7    UBS SECURITIES LLC  SICAV LATAM HEDGE.CAYMAN_UBS    01/03/2018  2373818
# 8    UBS SECURITIES LLC  SICAV LATAM HEDGE.CAYMAN_UBS    01/03/2018  2373818
# 9    UBS SECURITIES LLC                BD_CLIENTS_UBS    01/03/2018  2210476
# 10   UBS SECURITIES LLC                BD_CLIENTS_UBS    01/03/2018  2939469
# 11   UBS SECURITIES LLC           PRIVATE_DEFAULT_UBS    01/03/2018  B1VZ486
# 12   UBS SECURITIES LLC                BD_CLIENTS_UBS    01/03/2018  B0LXSX6
# 13   UBS SECURITIES LLC              TREAS_OPS.CAYMAN    01/03/2018  2399450
# 14   UBS SECURITIES LLC              TREAS_OPS.CAYMAN    01/03/2018  2136646
# 15   UBS SECURITIES LLC              TREAS_OPS.CAYMAN    01/03/2018  2259101
# 16   UBS SECURITIES LLC              TREAS_OPS.CAYMAN    01/03/2018  B0LLFT5
# 17   UBS SECURITIES LLC              TREAS_OPS.CAYMAN    01/03/2018  2680303
# 18   UBS SECURITIES LLC              TREAS_OPS.CAYMAN    01/03/2018  2373818
# 19   UBS SECURITIES LLC              TREAS_OPS.CAYMAN    01/03/2018  2373818
# 20   UBS SECURITIES LLC              TREAS_OPS.CAYMAN    01/03/2018  B605C22
# 21   UBS SECURITIES LLC              TREAS_OPS.CAYMAN    01/03/2018  B29FC81
# 22   UBS SECURITIES LLC              TREAS_OPS.CAYMAN    01/03/2018  B29FC81
# 23   UBS SECURITIES LLC              TREAS_OPS.CAYMAN    01/03/2018  2402466
# 24   UBS SECURITIES LLC              TREAS_OPS.CAYMAN    01/03/2018  2369389
# 25   UBS SECURITIES LLC              TREAS_OPS.CAYMAN    01/03/2018  2840215
# 26   UBS SECURITIES LLC              TREAS_OPS.CAYMAN    01/03/2018  2821113
# 27   UBS SECURITIES LLC              TREAS_OPS.CAYMAN    01/03/2018  2289874
# 28   UBS SECURITIES LLC              TREAS_OPS.CAYMAN    01/03/2018  BD49WQ3
# 29   UBS SECURITIES LLC              TREAS_OPS.CAYMAN    01/03/2018  2149934
# ..                  ...                           ...           ...      ...
# 3   MORGAN STANLEY & CO                LOCAL_ADR_INTC    27/04/2018      NaN
# 4   MORGAN STANLEY & CO          ACOES_OFFSHORE_.INTC    27/04/2018      NaN
# 5   MORGAN STANLEY & CO          ACOES_OFFSHORE_.INTC    27/04/2018      NaN
# 6   MORGAN STANLEY & CO                LOCAL_ADR_INTC    27/04/2018      NaN
# 7   MORGAN STANLEY & CO                LOCAL_ADR_INTC    27/04/2018      NaN
# 8   MORGAN STANLEY & CO             LOCAL_ADR_MR.INTC    27/04/2018      NaN
# 9   MORGAN STANLEY & CO             LOCAL_ADR_MR.INTC    27/04/2018      NaN
# 10  MORGAN STANLEY & CO                LOCAL_ADR_INTC    27/04/2018      NaN
# 11  MORGAN STANLEY & CO                LOCAL_ADR_INTC    27/04/2018      NaN
# 12  MORGAN STANLEY & CO          ACOES_OFFSHORE_.INTC    27/04/2018      NaN
# 13  MORGAN STANLEY & CO                LOCAL_ADR_INTC    27/04/2018      NaN
# 14  MORGAN STANLEY & CO                LOCAL_ADR_INTC    27/04/2018      NaN
# 15  MORGAN STANLEY & CO           INTRADAY_PAIRS.INTC    27/04/2018      NaN
# 0   MORGAN STANLEY & CO                LOCAL_ADR_INTC    30/04/2018      NaN
# 1   MORGAN STANLEY & CO           ACOES_OFFSHORE_INTC    30/04/2018      NaN
# 2   MORGAN STANLEY & CO                LOCAL_ADR_INTC    30/04/2018      NaN
# 3   MORGAN STANLEY & CO                LOCAL_ADR_INTC    30/04/2018      NaN
# 4   MORGAN STANLEY & CO          ACOES_OFFSHORE_.INTC    30/04/2018      NaN
# 5   MORGAN STANLEY & CO          ACOES_OFFSHORE_.INTC    30/04/2018      NaN
# 6   MORGAN STANLEY & CO          ACOES_OFFSHORE_.INTC    30/04/2018      NaN
# 7   MORGAN STANLEY & CO                LOCAL_ADR_INTC    30/04/2018      NaN
# 8   MORGAN STANLEY & CO                LOCAL_ADR_INTC    30/04/2018      NaN
# 9   MORGAN STANLEY & CO             LOCAL_ADR_MR.INTC    30/04/2018      NaN
# 10  MORGAN STANLEY & CO             LOCAL_ADR_MR.INTC    30/04/2018      NaN
# 11  MORGAN STANLEY & CO                LOCAL_ADR_INTC    30/04/2018      NaN
# 12  MORGAN STANLEY & CO                LOCAL_ADR_INTC    30/04/2018      NaN
# 13  MORGAN STANLEY & CO          ACOES_OFFSHORE_.INTC    30/04/2018      NaN
# 14  MORGAN STANLEY & CO                LOCAL_ADR_INTC    30/04/2018      NaN
# 15  MORGAN STANLEY & CO                LOCAL_ADR_INTC    30/04/2018      NaN
# 16  MORGAN STANLEY & CO           INTRADAY_PAIRS.INTC    30/04/2018      NaN
#
#     Shares Quantity Ticker Corretoras conta
# 0                -2           AMZN US   ubs
# 1             -1000           TSLA US   ubs
# 2            -20000           PAGS US   ubs
# 3            -19800           ENIC US   ubs
# 4             -9930            ECH US   ubs
# 5             -9930            ECH US   ubs
# 6            -70510            EWZ US   ubs
# 7            -36660            EWW US   ubs
# 8            -36660            EWW US   ubs
# 9            -28387            BVN US   ubs
# 10             -313            VCO US   ubs
# 11          -210475            HYG US   ubs
# 12             -249            TAL US   ubs
# 13          -120255             TV US   ubs
# 14            -2214           BSAC US   ubs
# 15            -6338            TGT US   ubs
# 16           -41984            GME US   ubs
# 17          -183584            JCP US   ubs
# 18          -549652            EWW US   ubs
# 19          -549652            EWW US   ubs
# 20            -7414            EPU US   ubs
# 21           -17504            ECH US   ubs
# 22           -17504            ECH US   ubs
# 23           -46951            XLE US   ubs
# 24          -292411            XLP US   ubs
# 25           -50757            SPY US   ubs
# 26           -19792           SONC US   ubs
# 27            -6793            DRI US   ubs
# 28          -276184           BSMX US   ubs
# 29           -32291            BKE US   ubs
# ..              ...               ...   ...
# 3             -2540            TSU US  intc
# 4            -10200           GAPB MM  intc
# 5             -9700            LTM US  intc
# 6           -233195            EBR US  intc
# 7              -300            SID US  intc
# 8           -888474           VALE US  intc
# 9           -715027            PBR US  intc
# 10            -1500           ITUB US  intc
# 11           -36765            ERJ US  intc
# 12          -567700            FMG AU  intc
# 13            -2100            VIV US  intc
# 14            -6759            PBR US  intc
# 15           -11342           VALE US  intc
# 0              -400           BRFS US  intc
# 1           -200000            PBR US  intc
# 2             -2415          PBR/A US  intc
# 3             -7140            TSU US  intc
# 4            -10200           GAPB MM  intc
# 5            -13700            LTM US  intc
# 6              -210            PAC US  intc
# 7           -305595            EBR US  intc
# 8              -300            SID US  intc
# 9           -887672           VALE US  intc
# 10          -714778            PBR US  intc
# 11            -1500           ITUB US  intc
# 12           -11765            ERJ US  intc
# 13          -567700            FMG AU  intc
# 14            -2100            VIV US  intc
# 15            -6759            PBR US  intc
# 16           -11342           VALE US  intc
#
# [8205 rows x 11 columns]

# %%
dash.columns = ['account', 'asset', 'currency','accrual', 'pb', 'book','date','sedol', 'qt', 'ticker', 'conta']

# %%
dash = dash.drop(['account', 'sedol', 'qt'], axis=1)

# %%
dash['date'] = pd.to_datetime(dash['date'], format='%d/%m/%Y')

# %%
dash['month'] = dash['date'].dt.month

# %%
dash
# Out:
#                               asset currency      accrual  \
# 0                    Equity.AMZN US      USD     0.090000
# 1                    Equity.TSLA US      USD    -6.890000
# 2                    Equity.PAGS US      USD  -102.610000
# 3   ADR.ENIC US(Equity.ENELCHIL CI)      USD     0.000000
# 4                     Equity.ECH US      USD   -18.270000
# 5                     Equity.ECH US      USD   -32.200000
# 6                     Equity.EWZ US      USD    66.790000
# 7                     Equity.EWW US      USD   -63.860000
# 8                     Equity.EWW US      USD  -957.500000
# 9    ADR.BVN US(Equity.BUENAVC1 PE)      USD    13.620000
# 10     ADR.VCO US(Equity.CONCHA CI)      USD     0.000000
# 11                    Equity.HYG US      USD -1246.330000
# 12                    Equity.TAL US      USD     0.110000
# 13    ADR.TV US(Equity.TLEVICPO MM)      USD    59.210000
# 14      ADR.BSAC US(Equity.BSAN CI)      USD     2.090000
# 15                    Equity.TGT US      USD    13.700000
# 16                    Equity.GME US      USD   -13.980000
# 17                    Equity.JCP US      USD   -60.010000
# 18                    Equity.EWW US      USD  -957.500000
# 19                    Equity.EWW US      USD   -63.860000
# 20                    Equity.EPU US      USD   -23.840000
# 21                    Equity.ECH US      USD   -18.270000
# 22                    Equity.ECH US      USD   -32.200000
# 23                    Equity.XLE US      USD    91.260000
# 24                    Equity.XLP US      USD   448.960000
# 25                    Equity.SPY US      USD   390.760000
# 26                   Equity.SONC US      USD   -20.800000
# 27                    Equity.DRI US      USD    18.330000
# 28     ADR.BSMX US(Equity.BSMXB MM)      USD    56.710000
# 29                    Equity.BKE US      USD  -120.900000
# ..                              ...      ...          ...
# 3          ADR.TSU US(Equity.TIMP3)      USD     1.200000
# 4                    Equity.GAPB MM      MXN    60.290000
# 5         ADR.LTM US(Equity.LTM CI)      USD     5.500000
# 6          ADR.EBR US(Equity.ELET3)      USD   202.350000
# 7          ADR.SID US(Equity.CSNA3)      USD     0.100000
# 8         ADR.VALE US(Equity.VALE3)      USD   217.029465
# 9          ADR.PBR US(Equity.PETR3)      USD   163.881589
# 10        ADR.ITUB US(Equity.ITUB4)      USD     0.470000
# 11         ADR.ERJ US(Equity.EMBR3)      USD    20.320000
# 12                    Equity.FMG AU      AUD    85.240000
# 13         ADR.VIV US(Equity.VIVT4)      USD     0.620000
# 14         ADR.PBR US(Equity.PETR3)      USD     1.549138
# 15        ADR.VALE US(Equity.VALE3)      USD     2.770535
# 0         ADR.BRFS US(Equity.BRFS3)      USD     0.230000
# 1          ADR.PBR US(Equity.PETR3)      USD    46.131626
# 2        ADR.PBR/A US(Equity.PETR4)      USD     0.670000
# 3          ADR.TSU US(Equity.TIMP3)      USD     3.410000
# 4                    Equity.GAPB MM      MXN    59.610000
# 5         ADR.LTM US(Equity.LTM CI)      USD     7.860000
# 6        ADR.PAC US(Equity.GAPB MM)      USD     0.980000
# 7          ADR.EBR US(Equity.ELET3)      USD   278.590000
# 8          ADR.SID US(Equity.CSNA3)      USD     0.100000
# 9         ADR.VALE US(Equity.VALE3)      USD   216.019862
# 10         ADR.PBR US(Equity.PETR3)      USD   164.869356
# 11        ADR.ITUB US(Equity.ITUB4)      USD     0.460000
# 12         ADR.ERJ US(Equity.EMBR3)      USD     6.360000
# 13                    Equity.FMG AU      AUD    85.600000
# 14         ADR.VIV US(Equity.VIVT4)      USD     0.630000
# 15         ADR.PBR US(Equity.PETR3)      USD     1.559018
# 16        ADR.VALE US(Equity.VALE3)      USD     2.760138
#
#                      pb                          book       date    ticker  \
# 0    UBS SECURITIES LLC                BD_CLIENTS_UBS 2018-03-01   AMZN US
# 1    UBS SECURITIES LLC           PRIVATE_DEFAULT_UBS 2018-03-01   TSLA US
# 2    UBS SECURITIES LLC           PRIVATE_DEFAULT_UBS 2018-03-01   PAGS US
# 3    UBS SECURITIES LLC                BD_CLIENTS_UBS 2018-03-01   ENIC US
# 4    UBS SECURITIES LLC  SICAV LATAM HEDGE.CAYMAN_UBS 2018-03-01    ECH US
# 5    UBS SECURITIES LLC  SICAV LATAM HEDGE.CAYMAN_UBS 2018-03-01    ECH US
# 6    UBS SECURITIES LLC  SICAV LATAM HEDGE.CAYMAN_UBS 2018-03-01    EWZ US
# 7    UBS SECURITIES LLC  SICAV LATAM HEDGE.CAYMAN_UBS 2018-03-01    EWW US
# 8    UBS SECURITIES LLC  SICAV LATAM HEDGE.CAYMAN_UBS 2018-03-01    EWW US
# 9    UBS SECURITIES LLC                BD_CLIENTS_UBS 2018-03-01    BVN US
# 10   UBS SECURITIES LLC                BD_CLIENTS_UBS 2018-03-01    VCO US
# 11   UBS SECURITIES LLC           PRIVATE_DEFAULT_UBS 2018-03-01    HYG US
# 12   UBS SECURITIES LLC                BD_CLIENTS_UBS 2018-03-01    TAL US
# 13   UBS SECURITIES LLC              TREAS_OPS.CAYMAN 2018-03-01     TV US
# 14   UBS SECURITIES LLC              TREAS_OPS.CAYMAN 2018-03-01   BSAC US
# 15   UBS SECURITIES LLC              TREAS_OPS.CAYMAN 2018-03-01    TGT US
# 16   UBS SECURITIES LLC              TREAS_OPS.CAYMAN 2018-03-01    GME US
# 17   UBS SECURITIES LLC              TREAS_OPS.CAYMAN 2018-03-01    JCP US
# 18   UBS SECURITIES LLC              TREAS_OPS.CAYMAN 2018-03-01    EWW US
# 19   UBS SECURITIES LLC              TREAS_OPS.CAYMAN 2018-03-01    EWW US
# 20   UBS SECURITIES LLC              TREAS_OPS.CAYMAN 2018-03-01    EPU US
# 21   UBS SECURITIES LLC              TREAS_OPS.CAYMAN 2018-03-01    ECH US
# 22   UBS SECURITIES LLC              TREAS_OPS.CAYMAN 2018-03-01    ECH US
# 23   UBS SECURITIES LLC              TREAS_OPS.CAYMAN 2018-03-01    XLE US
# 24   UBS SECURITIES LLC              TREAS_OPS.CAYMAN 2018-03-01    XLP US
# 25   UBS SECURITIES LLC              TREAS_OPS.CAYMAN 2018-03-01    SPY US
# 26   UBS SECURITIES LLC              TREAS_OPS.CAYMAN 2018-03-01   SONC US
# 27   UBS SECURITIES LLC              TREAS_OPS.CAYMAN 2018-03-01    DRI US
# 28   UBS SECURITIES LLC              TREAS_OPS.CAYMAN 2018-03-01   BSMX US
# 29   UBS SECURITIES LLC              TREAS_OPS.CAYMAN 2018-03-01    BKE US
# ..                  ...                           ...        ...       ...
# 3   MORGAN STANLEY & CO                LOCAL_ADR_INTC 2018-04-27    TSU US
# 4   MORGAN STANLEY & CO          ACOES_OFFSHORE_.INTC 2018-04-27   GAPB MM
# 5   MORGAN STANLEY & CO          ACOES_OFFSHORE_.INTC 2018-04-27    LTM US
# 6   MORGAN STANLEY & CO                LOCAL_ADR_INTC 2018-04-27    EBR US
# 7   MORGAN STANLEY & CO                LOCAL_ADR_INTC 2018-04-27    SID US
# 8   MORGAN STANLEY & CO             LOCAL_ADR_MR.INTC 2018-04-27   VALE US
# 9   MORGAN STANLEY & CO             LOCAL_ADR_MR.INTC 2018-04-27    PBR US
# 10  MORGAN STANLEY & CO                LOCAL_ADR_INTC 2018-04-27   ITUB US
# 11  MORGAN STANLEY & CO                LOCAL_ADR_INTC 2018-04-27    ERJ US
# 12  MORGAN STANLEY & CO          ACOES_OFFSHORE_.INTC 2018-04-27    FMG AU
# 13  MORGAN STANLEY & CO                LOCAL_ADR_INTC 2018-04-27    VIV US
# 14  MORGAN STANLEY & CO                LOCAL_ADR_INTC 2018-04-27    PBR US
# 15  MORGAN STANLEY & CO           INTRADAY_PAIRS.INTC 2018-04-27   VALE US
# 0   MORGAN STANLEY & CO                LOCAL_ADR_INTC 2018-04-30   BRFS US
# 1   MORGAN STANLEY & CO           ACOES_OFFSHORE_INTC 2018-04-30    PBR US
# 2   MORGAN STANLEY & CO                LOCAL_ADR_INTC 2018-04-30  PBR/A US
# 3   MORGAN STANLEY & CO                LOCAL_ADR_INTC 2018-04-30    TSU US
# 4   MORGAN STANLEY & CO          ACOES_OFFSHORE_.INTC 2018-04-30   GAPB MM
# 5   MORGAN STANLEY & CO          ACOES_OFFSHORE_.INTC 2018-04-30    LTM US
# 6   MORGAN STANLEY & CO          ACOES_OFFSHORE_.INTC 2018-04-30    PAC US
# 7   MORGAN STANLEY & CO                LOCAL_ADR_INTC 2018-04-30    EBR US
# 8   MORGAN STANLEY & CO                LOCAL_ADR_INTC 2018-04-30    SID US
# 9   MORGAN STANLEY & CO             LOCAL_ADR_MR.INTC 2018-04-30   VALE US
# 10  MORGAN STANLEY & CO             LOCAL_ADR_MR.INTC 2018-04-30    PBR US
# 11  MORGAN STANLEY & CO                LOCAL_ADR_INTC 2018-04-30   ITUB US
# 12  MORGAN STANLEY & CO                LOCAL_ADR_INTC 2018-04-30    ERJ US
# 13  MORGAN STANLEY & CO          ACOES_OFFSHORE_.INTC 2018-04-30    FMG AU
# 14  MORGAN STANLEY & CO                LOCAL_ADR_INTC 2018-04-30    VIV US
# 15  MORGAN STANLEY & CO                LOCAL_ADR_INTC 2018-04-30    PBR US
# 16  MORGAN STANLEY & CO           INTRADAY_PAIRS.INTC 2018-04-30   VALE US
#
#    conta  month
# 0    ubs      3
# 1    ubs      3
# 2    ubs      3
# 3    ubs      3
# 4    ubs      3
# 5    ubs      3
# 6    ubs      3
# 7    ubs      3
# 8    ubs      3
# 9    ubs      3
# 10   ubs      3
# 11   ubs      3
# 12   ubs      3
# 13   ubs      3
# 14   ubs      3
# 15   ubs      3
# 16   ubs      3
# 17   ubs      3
# 18   ubs      3
# 19   ubs      3
# 20   ubs      3
# 21   ubs      3
# 22   ubs      3
# 23   ubs      3
# 24   ubs      3
# 25   ubs      3
# 26   ubs      3
# 27   ubs      3
# 28   ubs      3
# 29   ubs      3
# ..   ...    ...
# 3   intc      4
# 4   intc      4
# 5   intc      4
# 6   intc      4
# 7   intc      4
# 8   intc      4
# 9   intc      4
# 10  intc      4
# 11  intc      4
# 12  intc      4
# 13  intc      4
# 14  intc      4
# 15  intc      4
# 0   intc      4
# 1   intc      4
# 2   intc      4
# 3   intc      4
# 4   intc      4
# 5   intc      4
# 6   intc      4
# 7   intc      4
# 8   intc      4
# 9   intc      4
# 10  intc      4
# 11  intc      4
# 12  intc      4
# 13  intc      4
# 14  intc      4
# 15  intc      4
# 16  intc      4
#
# [8205 rows x 9 columns]

# %%
dash_by_book = dash.groupby(by=['month', 'conta', 'pb', 'book', 'currency']).sum().reset_index()

# %%
dash_by_book = dash_by_book[dash_by_book['accrual']!=0].reset_index(drop=True)

# %%
dash_batimento = dash_by_book.groupby(by=['month', 'conta', 'currency']).sum().reset_index()

# %%
dict_accrual = [2290.07, 2600.76,-1.23,-410018.67,-193547.92, -747445.48, -32656.22, 2492.32, 1482.73, 6117.58,
                                 -1.07, -999326.27, -152710.77, -721047.90, -0]

# %%
dash_batimento['accrual_cayman'] = dict_accrual

# %%
dash_batimento['ajuste'] = dash_batimento['accrual_cayman']/dash_batimento['accrual']

# %%
dash_batimento
# Out:
#     month   conta currency        accrual  accrual_cayman    ajuste
# 0       3    intc      AUD    1476.950000         2290.07  1.550540
# 1       3    intc      USD    1632.980000         2600.76  1.592647
# 2       3  morgan      GBP      -0.870000           -1.23  1.413793
# 3       3  morgan      MXN -291605.460000      -410018.67  1.406073
# 4       3  morgan      USD -135346.820000      -193547.92  1.430015
# 5       3     ubs      MXN -530884.390000      -747445.48  1.407925
# 6       3     ubs      USD  -48126.635752       -32656.22  0.678548
# 7       4    intc      AUD    1722.440000         2492.32  1.446971
# 8       4    intc      MXN     952.450000         1482.73  1.556754
# 9       4    intc      USD    6117.580000         6117.58  1.000000
# 10      4  morgan      GBP      -0.750000           -1.07  1.426667
# 11      4  morgan      MXN -682058.920000      -999326.27  1.465161
# 12      4  morgan      USD -109195.200000      -152710.77  1.398512
# 13      4     ubs      MXN -503069.330000      -721047.90  1.433297
# 14      4     ubs      USD   -9565.526467            0.00 -0.000000

# %%
dash_ajustado = pd.merge(dash_by_book, dash_batimento, on=['month', 'conta', 'currency'], how='left')

# %%
dash_ajustado['accrual_x'] = dash_ajustado['accrual_x']*dash_ajustado['ajuste']

# %%
dash_ajustado_check = dash_ajustado.groupby(['month', 'conta', 'currency']).sum().drop(['accrual_y', 'accrual_cayman', 
                                                                                        'ajuste'], axis=1)

# %%
dash_ajustado_check['accrual_cayman'] = dict_accrual

# %%
dash_ajustado_check
# Out:
#                        accrual_x  accrual_cayman
# month conta  currency
# 3     intc   AUD         2290.07         2290.07
#              USD         2600.76         2600.76
#       morgan GBP           -1.23           -1.23
#              MXN      -410018.67      -410018.67
#              USD      -193547.92      -193547.92
#       ubs    MXN      -747445.48      -747445.48
#              USD       -32656.22       -32656.22
# 4     intc   AUD         2492.32         2492.32
#              MXN         1482.73         1482.73
#              USD         6117.58         6117.58
#       morgan GBP           -1.07           -1.07
#              MXN      -999326.27      -999326.27
#              USD      -152710.77      -152710.77
#       ubs    MXN      -721047.90      -721047.90
#              USD            0.00            0.00

# %%
dash_ajustado = dash_ajustado.drop(['accrual_y', 'accrual_cayman', 'ajuste'], axis=1)

# %%
dash_ajustado[dash_ajustado.month==3].drop(['month'], axis=1).to_excel('batimento_marco.xlsx', index=False)

# %%
dash_ajustado[dash_ajustado.month==4].drop(['month'], axis=1).to_excel('batimento_abril.xlsx', index=False)
